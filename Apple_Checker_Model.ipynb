# %%
# intall the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id':'1RkHuvc_TAtrMXMrWsx5AX1DdGL6352aI'})
download.GetContentFile('dataset2.zip')

# !unzip dataset2.zip
# Out:
# Archive:  dataset2.zip
#    creating: dataset2/
#    creating: dataset2/test/
#    creating: dataset2/test/notApples/
#   inflating: dataset2/test/notApples/hqdefault.jpg
#   inflating: dataset2/test/notApples/ft_train_and_val_acc_smooth_graph.png
#   inflating: dataset2/test/notApples/ft_train_and_val_loss_smooth_graph.png
#   inflating: dataset2/test/notApples/ft_training_and_val_acc_graph.png
#   inflating: dataset2/test/notApples/ft_training_and_val_loss_graph.png
#   inflating: dataset2/test/notApples/0_100pi.jpg
#   inflating: dataset2/test/notApples/1_100pi.jpg
#   inflating: dataset2/test/notApples/2_100pi.jpg
#   inflating: dataset2/test/notApples/4_100pi.jpg
#   inflating: dataset2/test/notApples/5_100pi.jpg
#   inflating: dataset2/test/notApples/6_100pi.jpg
#   inflating: dataset2/test/notApples/22_100t.jpg
#   inflating: dataset2/test/notApples/23_100t.jpg
#   inflating: dataset2/test/notApples/29_100t.jpg
#   inflating: dataset2/test/notApples/30_100t.jpg
#   inflating: dataset2/test/notApples/33_100t.jpg
#   inflating: dataset2/test/notApples/45_100t.jpg
#   inflating: dataset2/test/notApples/46_100t.jpg
#   inflating: dataset2/test/notApples/58_100t.jpg
#   inflating: dataset2/test/notApples/13_100m.jpg
#   inflating: dataset2/test/notApples/15_100m.jpg
#   inflating: dataset2/test/notApples/16_100m.jpg
#   inflating: dataset2/test/notApples/17_100m.jpg
#   inflating: dataset2/test/notApples/18_100m.jpg
#   inflating: dataset2/test/notApples/19_100m.jpg
#   inflating: dataset2/test/notApples/20_100m.jpg
#   inflating: dataset2/test/notApples/0_100p.jpg
#   inflating: dataset2/test/notApples/10_100p.jpg
#   inflating: dataset2/test/notApples/11_100p.jpg
#   inflating: dataset2/test/notApples/12_100p.jpg
#   inflating: dataset2/test/notApples/13_100p.jpg
#   inflating: dataset2/test/notApples/14_100p.jpg
#   inflating: dataset2/test/notApples/15_100p.jpg
#   inflating: dataset2/test/notApples/1_100p.jpg
#   inflating: dataset2/test/notApples/2_100p.jpg
#   inflating: dataset2/test/notApples/18_100cl.jpg
#   inflating: dataset2/test/notApples/19_100cl.jpg
#   inflating: dataset2/test/notApples/20_100cl.jpg
#   inflating: dataset2/test/notApples/21_100cl.jpg
#   inflating: dataset2/test/notApples/22_100cl.jpg
#   inflating: dataset2/test/notApples/23_100cl.jpg
#   inflating: dataset2/test/notApples/24_100cl.jpg
#   inflating: dataset2/test/notApples/25_100cl.jpg
#   inflating: dataset2/test/notApples/14_100c.jpg
#   inflating: dataset2/test/notApples/15_100c.jpg
#   inflating: dataset2/test/notApples/16_100c.jpg
#   inflating: dataset2/test/notApples/21_100c.jpg
#   inflating: dataset2/test/notApples/32_100c.jpg
#   inflating: dataset2/test/notApples/33_100c.jpg
#   inflating: dataset2/test/notApples/34_100c.jpg
#   inflating: dataset2/test/notApples/0_100oo.jpg
#   inflating: dataset2/test/notApples/10_100oo.jpg
#   inflating: dataset2/test/notApples/11_100oo.jpg
#   inflating: dataset2/test/notApples/12_100oo.jpg
#   inflating: dataset2/test/notApples/13_100oo.jpg
#   inflating: dataset2/test/notApples/1_100oo.jpg
#   inflating: dataset2/test/notApples/2_100oo.jpg
#   inflating: dataset2/test/notApples/0_100a.jpg
#   inflating: dataset2/test/notApples/10_100a.jpg
#   inflating: dataset2/test/notApples/11_100a.jpg
#   inflating: dataset2/test/notApples/12_100a.jpg
#   inflating: dataset2/test/notApples/13_100a.jpg
#   inflating: dataset2/test/notApples/1_100a.jpg
#   inflating: dataset2/test/notApples/2_100a.jpg
#   inflating: dataset2/test/notApples/38_100bb.jpg
#   inflating: dataset2/test/notApples/39_100bb.jpg
#   inflating: dataset2/test/notApples/40_100bb.jpg
#   inflating: dataset2/test/notApples/41_100bb.jpg
#   inflating: dataset2/test/notApples/42_100bb.jpg
#   inflating: dataset2/test/notApples/43_100bb.jpg
#    creating: dataset2/test/Apples/
#   inflating: dataset2/test/Apples/20_100g.jpg
#   inflating: dataset2/test/Apples/21_100g.jpg
#   inflating: dataset2/test/Apples/321_100g.jpg
#   inflating: dataset2/test/Apples/322_100g.jpg
#   inflating: dataset2/test/Apples/323_100g.jpg
#   inflating: dataset2/test/Apples/324_100g.jpg
#   inflating: dataset2/test/Apples/325_100g.jpg
#   inflating: dataset2/test/Apples/326_100g.jpg
#   inflating: dataset2/test/Apples/327_100g.jpg
#   inflating: dataset2/test/Apples/32_100g.jpg
#   inflating: dataset2/test/Apples/33_100g.jpg
#   inflating: dataset2/test/Apples/35_100g.jpg
#   inflating: dataset2/test/Apples/36_100g.jpg
#   inflating: dataset2/test/Apples/37_100g.jpg
#   inflating: dataset2/test/Apples/3_100g.jpg
#   inflating: dataset2/test/Apples/41_100g.jpg
#   inflating: dataset2/test/Apples/42_100g.jpg
#   inflating: dataset2/test/Apples/43_100g.jpg
#   inflating: dataset2/test/Apples/44_100g.jpg
#   inflating: dataset2/test/Apples/45_100g.jpg
#   inflating: dataset2/test/Apples/46_100g.jpg
#   inflating: dataset2/test/Apples/47_100g.jpg
#   inflating: dataset2/test/Apples/48_100g.jpg
#   inflating: dataset2/test/Apples/49_100g.jpg
#   inflating: dataset2/test/Apples/4_100g.jpg
#   inflating: dataset2/test/Apples/50_100g.jpg
#   inflating: dataset2/test/Apples/51_100g.jpg
#   inflating: dataset2/test/Apples/57_100g.jpg
#   inflating: dataset2/test/Apples/58_100g.jpg
#   inflating: dataset2/test/Apples/59_100g.jpg
#   inflating: dataset2/test/Apples/5_100g.jpg
#   inflating: dataset2/test/Apples/60_100g.jpg
#   inflating: dataset2/test/Apples/61_100g.jpg
#   inflating: dataset2/test/Apples/62_100g.jpg
#   inflating: dataset2/test/Apples/63_100g.jpg
#   inflating: dataset2/test/Apples/64_100g.jpg
#   inflating: dataset2/test/Apples/65_100g.jpg
#   inflating: dataset2/test/Apples/66_100g.jpg
#   inflating: dataset2/test/Apples/67_100g.jpg
#   inflating: dataset2/test/Apples/68_100g.jpg
#   inflating: dataset2/test/Apples/69_100g.jpg
#   inflating: dataset2/test/Apples/6_100g.jpg
#   inflating: dataset2/test/Apples/70_100g.jpg
#   inflating: dataset2/test/Apples/71_100g.jpg
#   inflating: dataset2/test/Apples/72_100g.jpg
#   inflating: dataset2/test/Apples/73_100g.jpg
#   inflating: dataset2/test/Apples/74_100g.jpg
#   inflating: dataset2/test/Apples/75_100g.jpg
#   inflating: dataset2/test/Apples/76_100g.jpg
#   inflating: dataset2/test/Apples/77_100g.jpg
#   inflating: dataset2/test/Apples/78_100g.jpg
#   inflating: dataset2/test/Apples/79_100g.jpg
#   inflating: dataset2/test/Apples/7_100g.jpg
#   inflating: dataset2/test/Apples/80_100g.jpg
#   inflating: dataset2/test/Apples/81_100g.jpg
#   inflating: dataset2/test/Apples/82_100g.jpg
#   inflating: dataset2/test/Apples/83_100g.jpg
#   inflating: dataset2/test/Apples/84_100g.jpg
#   inflating: dataset2/test/Apples/85_100g.jpg
#   inflating: dataset2/test/Apples/86_100g.jpg
#   inflating: dataset2/test/Apples/87_100g.jpg
#   inflating: dataset2/test/Apples/88_100g.jpg
#   inflating: dataset2/test/Apples/89_100g.jpg
#   inflating: dataset2/test/Apples/8_100g.jpg
#   inflating: dataset2/test/Apples/90_100g.jpg
#   inflating: dataset2/test/Apples/91_100g.jpg
#   inflating: dataset2/test/Apples/92_100g.jpg
#   inflating: dataset2/test/Apples/93_100g.jpg
#   inflating: dataset2/test/Apples/94_100g.jpg
#   inflating: dataset2/test/Apples/95_100g.jpg
#   inflating: dataset2/test/Apples/96_100g.jpg
#   inflating: dataset2/test/Apples/97_100g.jpg
#   inflating: dataset2/test/Apples/98_100g.jpg
#   inflating: dataset2/test/Apples/99_100g.jpg
#   inflating: dataset2/test/Apples/9_100g.jpg
#   inflating: dataset2/test/Apples/r_321_100g.jpg
#   inflating: dataset2/test/Apples/r_322_100g.jpg
#   inflating: dataset2/test/Apples/r_323_100g.jpg
#   inflating: dataset2/test/Apples/r_324_100g.jpg
#   inflating: dataset2/test/Apples/r_325_100g.jpg
#   inflating: dataset2/test/Apples/r_326_100g.jpg
#   inflating: dataset2/test/Apples/r_327_100g.jpg
#   inflating: dataset2/test/Apples/r_32_100g.jpg
#   inflating: dataset2/test/Apples/r_33_100g.jpg
#   inflating: dataset2/test/Apples/r_34_100g.jpg
#   inflating: dataset2/test/Apples/r_35_100g.jpg
#   inflating: dataset2/test/Apples/r_36_100g.jpg
#   inflating: dataset2/test/Apples/r_37_100g.jpg
#   inflating: dataset2/test/Apples/r_38_100g.jpg
#   inflating: dataset2/test/Apples/r_39_100g.jpg
#   inflating: dataset2/test/Apples/r_3_100g.jpg
#   inflating: dataset2/test/Apples/r_40_100g.jpg
#   inflating: dataset2/test/Apples/r_41_100g.jpg
#   inflating: dataset2/test/Apples/r_42_100g.jpg
#   inflating: dataset2/test/Apples/r_43_100g.jpg
#   inflating: dataset2/test/Apples/r_44_100g.jpg
#   inflating: dataset2/test/Apples/r_45_100g.jpg
#   inflating: dataset2/test/Apples/r_46_100g.jpg
#   inflating: dataset2/test/Apples/r_47_100g.jpg
#   inflating: dataset2/test/Apples/r_48_100g.jpg
#   inflating: dataset2/test/Apples/r_49_100g.jpg
#   inflating: dataset2/test/Apples/r_4_100g.jpg
#   inflating: dataset2/test/Apples/r_50_100g.jpg
#   inflating: dataset2/test/Apples/r_51_100g.jpg
#   inflating: dataset2/test/Apples/r_52_100g.jpg
#   inflating: dataset2/test/Apples/r_53_100g.jpg
#   inflating: dataset2/test/Apples/r_54_100g.jpg
#   inflating: dataset2/test/Apples/r_55_100g.jpg
#   inflating: dataset2/test/Apples/r_56_100g.jpg
#   inflating: dataset2/test/Apples/r_57_100g.jpg
#   inflating: dataset2/test/Apples/r_58_100g.jpg
#   inflating: dataset2/test/Apples/r_59_100g.jpg
#   inflating: dataset2/test/Apples/r_5_100g.jpg
#   inflating: dataset2/test/Apples/r_60_100g.jpg
#   inflating: dataset2/test/Apples/r_61_100g.jpg
#   inflating: dataset2/test/Apples/r_62_100g.jpg
#   inflating: dataset2/test/Apples/r_63_100g.jpg
#   inflating: dataset2/test/Apples/r_64_100g.jpg
#   inflating: dataset2/test/Apples/r_65_100g.jpg
#   inflating: dataset2/test/Apples/r_66_100g.jpg
#   inflating: dataset2/test/Apples/r_67_100g.jpg
#   inflating: dataset2/test/Apples/r_68_100g.jpg
#   inflating: dataset2/test/Apples/r_69_100g.jpg
#   inflating: dataset2/test/Apples/r_6_100g.jpg
#   inflating: dataset2/test/Apples/r_70_100g.jpg
#   inflating: dataset2/test/Apples/r_71_100g.jpg
#   inflating: dataset2/test/Apples/r_72_100g.jpg
#   inflating: dataset2/test/Apples/r_73_100g.jpg
#   inflating: dataset2/test/Apples/r_74_100g.jpg
#   inflating: dataset2/test/Apples/r_75_100g.jpg
#   inflating: dataset2/test/Apples/r_76_100g.jpg
#   inflating: dataset2/test/Apples/r_77_100g.jpg
#   inflating: dataset2/test/Apples/r_78_100g.jpg
#   inflating: dataset2/test/Apples/r_79_100g.jpg
#   inflating: dataset2/test/Apples/r_7_100g.jpg
#   inflating: dataset2/test/Apples/r_80_100g.jpg
#   inflating: dataset2/test/Apples/r_81_100g.jpg
#   inflating: dataset2/test/Apples/r_82_100g.jpg
#   inflating: dataset2/test/Apples/r_83_100g.jpg
#   inflating: dataset2/test/Apples/r_84_100g.jpg
#   inflating: dataset2/test/Apples/r_85_100g.jpg
#   inflating: dataset2/test/Apples/r_86_100g.jpg
#   inflating: dataset2/test/Apples/r_87_100g.jpg
#   inflating: dataset2/test/Apples/r_88_100g.jpg
#   inflating: dataset2/test/Apples/r_89_100g.jpg
#   inflating: dataset2/test/Apples/r_8_100g.jpg
#   inflating: dataset2/test/Apples/r_90_100g.jpg
#   inflating: dataset2/test/Apples/r_91_100g.jpg
#   inflating: dataset2/test/Apples/r_92_100g.jpg
#   inflating: dataset2/test/Apples/r_93_100g.jpg
#   inflating: dataset2/test/Apples/r_94_100g.jpg
#   inflating: dataset2/test/Apples/r_95_100g.jpg
#   inflating: dataset2/test/Apples/r_96_100g.jpg
#   inflating: dataset2/test/Apples/r_97_100g.jpg
#   inflating: dataset2/test/Apples/r_98_100g.jpg
#   inflating: dataset2/test/Apples/r_99_100g.jpg
#   inflating: dataset2/test/Apples/r_9_100g.jpg
#   inflating: dataset2/test/Apples/321_100.jpg
#   inflating: dataset2/test/Apples/322_100.jpg
#   inflating: dataset2/test/Apples/323_100.jpg
#   inflating: dataset2/test/Apples/324_100.jpg
#   inflating: dataset2/test/Apples/325_100.jpg
#   inflating: dataset2/test/Apples/326_100.jpg
#   inflating: dataset2/test/Apples/327_100.jpg
#   inflating: dataset2/test/Apples/32_100.jpg
#   inflating: dataset2/test/Apples/33_100.jpg
#   inflating: dataset2/test/Apples/34_100.jpg
#   inflating: dataset2/test/Apples/36_100.jpg
#   inflating: dataset2/test/Apples/37_100.jpg
#   inflating: dataset2/test/Apples/38_100.jpg
#   inflating: dataset2/test/Apples/3_100.jpg
#   inflating: dataset2/test/Apples/41_100.jpg
#   inflating: dataset2/test/Apples/42_100.jpg
#   inflating: dataset2/test/Apples/43_100.jpg
#   inflating: dataset2/test/Apples/44_100.jpg
#   inflating: dataset2/test/Apples/45_100.jpg
#   inflating: dataset2/test/Apples/46_100.jpg
#   inflating: dataset2/test/Apples/47_100.jpg
#   inflating: dataset2/test/Apples/48_100.jpg
#   inflating: dataset2/test/Apples/49_100.jpg
#   inflating: dataset2/test/Apples/4_100.jpg
#   inflating: dataset2/test/Apples/50_100.jpg
#   inflating: dataset2/test/Apples/51_100.jpg
#   inflating: dataset2/test/Apples/57_100.jpg
#   inflating: dataset2/test/Apples/58_100.jpg
#   inflating: dataset2/test/Apples/59_100.jpg
#   inflating: dataset2/test/Apples/5_100.jpg
#   inflating: dataset2/test/Apples/60_100.jpg
#   inflating: dataset2/test/Apples/61_100.jpg
#   inflating: dataset2/test/Apples/62_100.jpg
#   inflating: dataset2/test/Apples/63_100.jpg
#   inflating: dataset2/test/Apples/64_100.jpg
#   inflating: dataset2/test/Apples/65_100.jpg
#   inflating: dataset2/test/Apples/66_100.jpg
#   inflating: dataset2/test/Apples/67_100.jpg
#   inflating: dataset2/test/Apples/68_100.jpg
#   inflating: dataset2/test/Apples/69_100.jpg
#   inflating: dataset2/test/Apples/6_100.jpg
#   inflating: dataset2/test/Apples/70_100.jpg
#   inflating: dataset2/test/Apples/71_100.jpg
#   inflating: dataset2/test/Apples/72_100.jpg
#   inflating: dataset2/test/Apples/73_100.jpg
#   inflating: dataset2/test/Apples/74_100.jpg
#   inflating: dataset2/test/Apples/75_100.jpg
#   inflating: dataset2/test/Apples/76_100.jpg
#   inflating: dataset2/test/Apples/77_100.jpg
#   inflating: dataset2/test/Apples/78_100.jpg
#   inflating: dataset2/test/Apples/79_100.jpg
#   inflating: dataset2/test/Apples/7_100.jpg
#   inflating: dataset2/test/Apples/80_100.jpg
#   inflating: dataset2/test/Apples/81_100.jpg
#   inflating: dataset2/test/Apples/82_100.jpg
#   inflating: dataset2/test/Apples/83_100.jpg
#   inflating: dataset2/test/Apples/84_100.jpg
#   inflating: dataset2/test/Apples/85_100.jpg
#   inflating: dataset2/test/Apples/86_100.jpg
#   inflating: dataset2/test/Apples/87_100.jpg
#   inflating: dataset2/test/Apples/88_100.jpg
#   inflating: dataset2/test/Apples/89_100.jpg
#   inflating: dataset2/test/Apples/8_100.jpg
#   inflating: dataset2/test/Apples/90_100.jpg
#   inflating: dataset2/test/Apples/91_100.jpg
#   inflating: dataset2/test/Apples/92_100.jpg
#   inflating: dataset2/test/Apples/93_100.jpg
#   inflating: dataset2/test/Apples/94_100.jpg
#   inflating: dataset2/test/Apples/95_100.jpg
#   inflating: dataset2/test/Apples/96_100.jpg
#   inflating: dataset2/test/Apples/97_100.jpg
#   inflating: dataset2/test/Apples/98_100.jpg
#   inflating: dataset2/test/Apples/99_100.jpg
#   inflating: dataset2/test/Apples/9_100.jpg
#   inflating: dataset2/test/Apples/r_321_100.jpg
#   inflating: dataset2/test/Apples/r_322_100.jpg
#   inflating: dataset2/test/Apples/r_323_100.jpg
#   inflating: dataset2/test/Apples/r_324_100.jpg
#   inflating: dataset2/test/Apples/r_325_100.jpg
#   inflating: dataset2/test/Apples/r_326_100.jpg
#   inflating: dataset2/test/Apples/r_327_100.jpg
#   inflating: dataset2/test/Apples/r_32_100.jpg
#   inflating: dataset2/test/Apples/r_33_100.jpg
#   inflating: dataset2/test/Apples/r_34_100.jpg
#   inflating: dataset2/test/Apples/r_35_100.jpg
#   inflating: dataset2/test/Apples/r_36_100.jpg
#   inflating: dataset2/test/Apples/r_37_100.jpg
#   inflating: dataset2/test/Apples/r_38_100.jpg
#   inflating: dataset2/test/Apples/r_39_100.jpg
#   inflating: dataset2/test/Apples/r_3_100.jpg
#   inflating: dataset2/test/Apples/r_40_100.jpg
#   inflating: dataset2/test/Apples/r_41_100.jpg
#   inflating: dataset2/test/Apples/r_42_100.jpg
#   inflating: dataset2/test/Apples/r_43_100.jpg
#   inflating: dataset2/test/Apples/r_44_100.jpg
#   inflating: dataset2/test/Apples/r_45_100.jpg
#   inflating: dataset2/test/Apples/r_46_100.jpg
#   inflating: dataset2/test/Apples/r_47_100.jpg
#   inflating: dataset2/test/Apples/r_48_100.jpg
#   inflating: dataset2/test/Apples/r_49_100.jpg
#   inflating: dataset2/test/Apples/r_4_100.jpg
#   inflating: dataset2/test/Apples/r_50_100.jpg
#   inflating: dataset2/test/Apples/r_51_100.jpg
#   inflating: dataset2/test/Apples/r_52_100.jpg
#   inflating: dataset2/test/Apples/r_53_100.jpg
#   inflating: dataset2/test/Apples/r_54_100.jpg
#   inflating: dataset2/test/Apples/r_55_100.jpg
#   inflating: dataset2/test/Apples/r_56_100.jpg
#   inflating: dataset2/test/Apples/r_57_100.jpg
#   inflating: dataset2/test/Apples/r_58_100.jpg
#   inflating: dataset2/test/Apples/r_59_100.jpg
#   inflating: dataset2/test/Apples/r_5_100.jpg
#   inflating: dataset2/test/Apples/r_60_100.jpg
#   inflating: dataset2/test/Apples/r_61_100.jpg
#   inflating: dataset2/test/Apples/r_62_100.jpg
#   inflating: dataset2/test/Apples/r_63_100.jpg
#   inflating: dataset2/test/Apples/r_64_100.jpg
#   inflating: dataset2/test/Apples/r_65_100.jpg
#   inflating: dataset2/test/Apples/r_66_100.jpg
#   inflating: dataset2/test/Apples/r_67_100.jpg
#   inflating: dataset2/test/Apples/r_68_100.jpg
#   inflating: dataset2/test/Apples/r_69_100.jpg
#   inflating: dataset2/test/Apples/r_6_100.jpg
#   inflating: dataset2/test/Apples/r_70_100.jpg
#   inflating: dataset2/test/Apples/r_71_100.jpg
#   inflating: dataset2/test/Apples/r_72_100.jpg
#   inflating: dataset2/test/Apples/r_73_100.jpg
#   inflating: dataset2/test/Apples/r_74_100.jpg
#   inflating: dataset2/test/Apples/r_75_100.jpg
#   inflating: dataset2/test/Apples/r_76_100.jpg
#   inflating: dataset2/test/Apples/r_77_100.jpg
#   inflating: dataset2/test/Apples/r_78_100.jpg
#   inflating: dataset2/test/Apples/r_79_100.jpg
#   inflating: dataset2/test/Apples/r_7_100.jpg
#   inflating: dataset2/test/Apples/r_80_100.jpg
#   inflating: dataset2/test/Apples/r_81_100.jpg
#   inflating: dataset2/test/Apples/r_82_100.jpg
#   inflating: dataset2/test/Apples/r_83_100.jpg
#   inflating: dataset2/test/Apples/r_84_100.jpg
#   inflating: dataset2/test/Apples/r_85_100.jpg
#   inflating: dataset2/test/Apples/r_86_100.jpg
#   inflating: dataset2/test/Apples/r_87_100.jpg
#   inflating: dataset2/test/Apples/r_88_100.jpg
#   inflating: dataset2/test/Apples/r_89_100.jpg
#   inflating: dataset2/test/Apples/r_8_100.jpg
#   inflating: dataset2/test/Apples/r_90_100.jpg
#   inflating: dataset2/test/Apples/r_91_100.jpg
#   inflating: dataset2/test/Apples/r_92_100.jpg
#   inflating: dataset2/test/Apples/r_93_100.jpg
#   inflating: dataset2/test/Apples/r_94_100.jpg
#   inflating: dataset2/test/Apples/r_95_100.jpg
#   inflating: dataset2/test/Apples/r_96_100.jpg
#   inflating: dataset2/test/Apples/r_97_100.jpg
#   inflating: dataset2/test/Apples/r_98_100.jpg
#   inflating: dataset2/test/Apples/r_99_100.jpg
#   inflating: dataset2/test/Apples/r_9_100.jpg
#   inflating: dataset2/test/Apples/311_100gB.jpg
#   inflating: dataset2/test/Apples/312_100gB.jpg
#   inflating: dataset2/test/Apples/313_100gB.jpg
#   inflating: dataset2/test/Apples/31_100gB.jpg
#   inflating: dataset2/test/Apples/32_100gB.jpg
#   inflating: dataset2/test/Apples/33_100gB.jpg
#   inflating: dataset2/test/Apples/34_100gB.jpg
#   inflating: dataset2/test/Apples/35_100gB.jpg
#   inflating: dataset2/test/Apples/36_100gB.jpg
#   inflating: dataset2/test/Apples/37_100gB.jpg
#   inflating: dataset2/test/Apples/3_100gB.jpg
#   inflating: dataset2/test/Apples/40_100gB.jpg
#   inflating: dataset2/test/Apples/41_100gB.jpg
#   inflating: dataset2/test/Apples/42_100gB.jpg
#   inflating: dataset2/test/Apples/43_100gB.jpg
#   inflating: dataset2/test/Apples/44_100gB.jpg
#   inflating: dataset2/test/Apples/45_100gB.jpg
#   inflating: dataset2/test/Apples/46_100gB.jpg
#   inflating: dataset2/test/Apples/47_100gB.jpg
#   inflating: dataset2/test/Apples/48_100gB.jpg
#   inflating: dataset2/test/Apples/49_100gB.jpg
#   inflating: dataset2/test/Apples/4_100gB.jpg
#   inflating: dataset2/test/Apples/53_100gB.jpg
#   inflating: dataset2/test/Apples/54_100gB.jpg
#   inflating: dataset2/test/Apples/55_100gB.jpg
#   inflating: dataset2/test/Apples/56_100gB.jpg
#   inflating: dataset2/test/Apples/57_100gB.jpg
#   inflating: dataset2/test/Apples/58_100gB.jpg
#   inflating: dataset2/test/Apples/59_100gB.jpg
#   inflating: dataset2/test/Apples/5_100gB.jpg
#   inflating: dataset2/test/Apples/60_100gB.jpg
#   inflating: dataset2/test/Apples/61_100gB.jpg
#   inflating: dataset2/test/Apples/62_100gB.jpg
#   inflating: dataset2/test/Apples/63_100gB.jpg
#   inflating: dataset2/test/Apples/64_100gB.jpg
#   inflating: dataset2/test/Apples/65_100gB.jpg
#   inflating: dataset2/test/Apples/66_100gB.jpg
#   inflating: dataset2/test/Apples/67_100gB.jpg
#   inflating: dataset2/test/Apples/68_100gB.jpg
#   inflating: dataset2/test/Apples/69_100gB.jpg
#   inflating: dataset2/test/Apples/6_100gB.jpg
#   inflating: dataset2/test/Apples/70_100gB.jpg
#   inflating: dataset2/test/Apples/71_100gB.jpg
#   inflating: dataset2/test/Apples/72_100gB.jpg
#   inflating: dataset2/test/Apples/73_100gB.jpg
#   inflating: dataset2/test/Apples/74_100gB.jpg
#   inflating: dataset2/test/Apples/75_100gB.jpg
#   inflating: dataset2/test/Apples/76_100gB.jpg
#   inflating: dataset2/test/Apples/77_100gB.jpg
#   inflating: dataset2/test/Apples/78_100gB.jpg
#   inflating: dataset2/test/Apples/79_100gB.jpg
#   inflating: dataset2/test/Apples/7_100gB.jpg
#   inflating: dataset2/test/Apples/80_100gB.jpg
#   inflating: dataset2/test/Apples/81_100gB.jpg
#   inflating: dataset2/test/Apples/82_100gB.jpg
#   inflating: dataset2/test/Apples/83_100gB.jpg
#   inflating: dataset2/test/Apples/84_100gB.jpg
#   inflating: dataset2/test/Apples/85_100gB.jpg
#   inflating: dataset2/test/Apples/86_100gB.jpg
#   inflating: dataset2/test/Apples/87_100gB.jpg
#   inflating: dataset2/test/Apples/88_100gB.jpg
#   inflating: dataset2/test/Apples/89_100gB.jpg
#   inflating: dataset2/test/Apples/8_100gB.jpg
#   inflating: dataset2/test/Apples/90_100gB.jpg
#   inflating: dataset2/test/Apples/91_100gB.jpg
#   inflating: dataset2/test/Apples/92_100gB.jpg
#   inflating: dataset2/test/Apples/93_100gB.jpg
#   inflating: dataset2/test/Apples/94_100gB.jpg
#   inflating: dataset2/test/Apples/95_100gB.jpg
#   inflating: dataset2/test/Apples/96_100gB.jpg
#   inflating: dataset2/test/Apples/97_100gB.jpg
#   inflating: dataset2/test/Apples/98_100gB.jpg
#   inflating: dataset2/test/Apples/99_100gB.jpg
#   inflating: dataset2/test/Apples/9_100gB.jpg
#   inflating: dataset2/test/Apples/r_321_100gB.jpg
#   inflating: dataset2/test/Apples/r_322_100gB.jpg
#   inflating: dataset2/test/Apples/r_323_100gB.jpg
#   inflating: dataset2/test/Apples/r_324_100gB.jpg
#   inflating: dataset2/test/Apples/r_325_100gB.jpg
#   inflating: dataset2/test/Apples/r_326_100gB.jpg
#   inflating: dataset2/test/Apples/r_327_100gB.jpg
#   inflating: dataset2/test/Apples/r_32_100gB.jpg
#   inflating: dataset2/test/Apples/r_33_100gB.jpg
#   inflating: dataset2/test/Apples/r_34_100gB.jpg
#   inflating: dataset2/test/Apples/r_35_100gB.jpg
#   inflating: dataset2/test/Apples/r_36_100gB.jpg
#   inflating: dataset2/test/Apples/r_37_100gB.jpg
#   inflating: dataset2/test/Apples/r_38_100gB.jpg
#   inflating: dataset2/test/Apples/r_39_100gB.jpg
#   inflating: dataset2/test/Apples/r_3_100gB.jpg
#   inflating: dataset2/test/Apples/r_40_100gB.jpg
#   inflating: dataset2/test/Apples/r_41_100gB.jpg
#   inflating: dataset2/test/Apples/r_42_100gB.jpg
#   inflating: dataset2/test/Apples/r_43_100gB.jpg
#   inflating: dataset2/test/Apples/r_44_100gB.jpg
#   inflating: dataset2/test/Apples/r_45_100gB.jpg
#   inflating: dataset2/test/Apples/r_46_100gB.jpg
#   inflating: dataset2/test/Apples/r_47_100gB.jpg
#   inflating: dataset2/test/Apples/r_48_100gB.jpg
#   inflating: dataset2/test/Apples/r_49_100gB.jpg
#   inflating: dataset2/test/Apples/r_4_100gB.jpg
#   inflating: dataset2/test/Apples/r_50_100gB.jpg
#   inflating: dataset2/test/Apples/r_51_100gB.jpg
#   inflating: dataset2/test/Apples/r_52_100gB.jpg
#   inflating: dataset2/test/Apples/r_53_100gB.jpg
#   inflating: dataset2/test/Apples/r_54_100gB.jpg
#   inflating: dataset2/test/Apples/r_55_100gB.jpg
#   inflating: dataset2/test/Apples/r_56_100gB.jpg
#   inflating: dataset2/test/Apples/r_57_100gB.jpg
#   inflating: dataset2/test/Apples/r_58_100gB.jpg
#   inflating: dataset2/test/Apples/r_59_100gB.jpg
#   inflating: dataset2/test/Apples/r_5_100gB.jpg
#   inflating: dataset2/test/Apples/r_60_100gB.jpg
#   inflating: dataset2/test/Apples/r_61_100gB.jpg
#   inflating: dataset2/test/Apples/r_62_100gB.jpg
#   inflating: dataset2/test/Apples/r_63_100gB.jpg
#   inflating: dataset2/test/Apples/r_64_100gB.jpg
#   inflating: dataset2/test/Apples/r_65_100gB.jpg
#   inflating: dataset2/test/Apples/r_66_100gB.jpg
#   inflating: dataset2/test/Apples/r_67_100gB.jpg
#   inflating: dataset2/test/Apples/r_68_100gB.jpg
#   inflating: dataset2/test/Apples/r_69_100gB.jpg
#   inflating: dataset2/test/Apples/r_6_100gB.jpg
#   inflating: dataset2/test/Apples/r_70_100gB.jpg
#   inflating: dataset2/test/Apples/r_71_100gB.jpg
#   inflating: dataset2/test/Apples/r_72_100gB.jpg
#   inflating: dataset2/test/Apples/r_73_100gB.jpg
#   inflating: dataset2/test/Apples/r_74_100gB.jpg
#   inflating: dataset2/test/Apples/r_75_100gB.jpg
#   inflating: dataset2/test/Apples/r_76_100gB.jpg
#   inflating: dataset2/test/Apples/r_77_100gB.jpg
#   inflating: dataset2/test/Apples/r_78_100gB.jpg
#   inflating: dataset2/test/Apples/r_79_100gB.jpg
#   inflating: dataset2/test/Apples/r_7_100gB.jpg
#   inflating: dataset2/test/Apples/r_80_100gB.jpg
#   inflating: dataset2/test/Apples/r_81_100gB.jpg
#   inflating: dataset2/test/Apples/r_82_100gB.jpg
#   inflating: dataset2/test/Apples/r_83_100gB.jpg
#   inflating: dataset2/test/Apples/r_84_100gB.jpg
#   inflating: dataset2/test/Apples/r_85_100gB.jpg
#   inflating: dataset2/test/Apples/r_86_100gB.jpg
#   inflating: dataset2/test/Apples/r_87_100gB.jpg
#   inflating: dataset2/test/Apples/r_88_100gB.jpg
#   inflating: dataset2/test/Apples/r_89_100gB.jpg
#   inflating: dataset2/test/Apples/r_8_100gB.jpg
#   inflating: dataset2/test/Apples/r_90_100gB.jpg
#   inflating: dataset2/test/Apples/r_91_100gB.jpg
#   inflating: dataset2/test/Apples/r_92_100gB.jpg
#   inflating: dataset2/test/Apples/r_93_100gB.jpg
#   inflating: dataset2/test/Apples/r_94_100gB.jpg
#   inflating: dataset2/test/Apples/r_95_100gB.jpg
#   inflating: dataset2/test/Apples/r_96_100gB.jpg
#   inflating: dataset2/test/Apples/r_97_100gB.jpg
#   inflating: dataset2/test/Apples/r_98_100gB.jpg
#   inflating: dataset2/test/Apples/r_99_100gB.jpg
#   inflating: dataset2/test/Apples/r_9_100gB.jpg
#   inflating: dataset2/test/Apples/321_100B.jpg
#   inflating: dataset2/test/Apples/322_100B.jpg
#   inflating: dataset2/test/Apples/323_100B.jpg
#   inflating: dataset2/test/Apples/324_100B.jpg
#   inflating: dataset2/test/Apples/325_100B.jpg
#   inflating: dataset2/test/Apples/326_100B.jpg
#   inflating: dataset2/test/Apples/327_100B.jpg
#   inflating: dataset2/test/Apples/32_100B.jpg
#   inflating: dataset2/test/Apples/33_100B.jpg
#   inflating: dataset2/test/Apples/34_100B.jpg
#   inflating: dataset2/test/Apples/35_100B.jpg
#   inflating: dataset2/test/Apples/36_100B.jpg
#   inflating: dataset2/test/Apples/37_100B.jpg
#   inflating: dataset2/test/Apples/3_100B.jpg
#   inflating: dataset2/test/Apples/41_100B.jpg
#   inflating: dataset2/test/Apples/42_100B.jpg
#   inflating: dataset2/test/Apples/43_100B.jpg
#   inflating: dataset2/test/Apples/44_100B.jpg
#   inflating: dataset2/test/Apples/45_100B.jpg
#   inflating: dataset2/test/Apples/46_100B.jpg
#   inflating: dataset2/test/Apples/47_100B.jpg
#   inflating: dataset2/test/Apples/48_100B.jpg
#   inflating: dataset2/test/Apples/49_100B.jpg
#   inflating: dataset2/test/Apples/4_100B.jpg
#   inflating: dataset2/test/Apples/50_100B.jpg
#   inflating: dataset2/test/Apples/53_100B.jpg
#   inflating: dataset2/test/Apples/54_100B.jpg
#   inflating: dataset2/test/Apples/55_100B.jpg
#   inflating: dataset2/test/Apples/56_100B.jpg
#   inflating: dataset2/test/Apples/57_100B.jpg
#   inflating: dataset2/test/Apples/58_100B.jpg
#   inflating: dataset2/test/Apples/59_100B.jpg
#   inflating: dataset2/test/Apples/5_100B.jpg
#   inflating: dataset2/test/Apples/60_100B.jpg
#   inflating: dataset2/test/Apples/61_100B.jpg
#   inflating: dataset2/test/Apples/62_100B.jpg
#   inflating: dataset2/test/Apples/63_100B.jpg
#   inflating: dataset2/test/Apples/64_100B.jpg
#   inflating: dataset2/test/Apples/65_100B.jpg
#   inflating: dataset2/test/Apples/66_100B.jpg
#   inflating: dataset2/test/Apples/67_100B.jpg
#   inflating: dataset2/test/Apples/68_100B.jpg
#   inflating: dataset2/test/Apples/69_100B.jpg
#   inflating: dataset2/test/Apples/6_100B.jpg
#   inflating: dataset2/test/Apples/70_100B.jpg
#   inflating: dataset2/test/Apples/71_100B.jpg
#   inflating: dataset2/test/Apples/72_100B.jpg
#   inflating: dataset2/test/Apples/73_100B.jpg
#   inflating: dataset2/test/Apples/74_100B.jpg
#   inflating: dataset2/test/Apples/75_100B.jpg
#   inflating: dataset2/test/Apples/76_100B.jpg
#   inflating: dataset2/test/Apples/77_100B.jpg
#   inflating: dataset2/test/Apples/78_100B.jpg
#   inflating: dataset2/test/Apples/79_100B.jpg
#   inflating: dataset2/test/Apples/7_100B.jpg
#   inflating: dataset2/test/Apples/80_100B.jpg
#   inflating: dataset2/test/Apples/81_100B.jpg
#   inflating: dataset2/test/Apples/82_100B.jpg
#   inflating: dataset2/test/Apples/83_100B.jpg
#   inflating: dataset2/test/Apples/84_100B.jpg
#   inflating: dataset2/test/Apples/85_100B.jpg
#   inflating: dataset2/test/Apples/86_100B.jpg
#   inflating: dataset2/test/Apples/87_100B.jpg
#   inflating: dataset2/test/Apples/88_100B.jpg
#   inflating: dataset2/test/Apples/89_100B.jpg
#   inflating: dataset2/test/Apples/8_100B.jpg
#   inflating: dataset2/test/Apples/90_100B.jpg
#   inflating: dataset2/test/Apples/91_100B.jpg
#   inflating: dataset2/test/Apples/92_100B.jpg
#   inflating: dataset2/test/Apples/93_100B.jpg
#   inflating: dataset2/test/Apples/94_100B.jpg
#   inflating: dataset2/test/Apples/95_100B.jpg
#   inflating: dataset2/test/Apples/96_100B.jpg
#   inflating: dataset2/test/Apples/97_100B.jpg
#   inflating: dataset2/test/Apples/98_100B.jpg
#   inflating: dataset2/test/Apples/99_100B.jpg
#   inflating: dataset2/test/Apples/9_100B.jpg
#   inflating: dataset2/test/Apples/r_321_100B.jpg
#   inflating: dataset2/test/Apples/r_322_100B.jpg
#   inflating: dataset2/test/Apples/r_323_100B.jpg
#   inflating: dataset2/test/Apples/r_324_100B.jpg
#   inflating: dataset2/test/Apples/r_325_100B.jpg
#   inflating: dataset2/test/Apples/r_326_100B.jpg
#   inflating: dataset2/test/Apples/r_327_100B.jpg
#   inflating: dataset2/test/Apples/r_32_100B.jpg
#   inflating: dataset2/test/Apples/r_33_100B.jpg
#   inflating: dataset2/test/Apples/r_34_100B.jpg
#   inflating: dataset2/test/Apples/r_35_100B.jpg
#   inflating: dataset2/test/Apples/r_36_100B.jpg
#   inflating: dataset2/test/Apples/r_37_100B.jpg
#   inflating: dataset2/test/Apples/r_38_100B.jpg
#   inflating: dataset2/test/Apples/r_39_100B.jpg
#   inflating: dataset2/test/Apples/r_3_100B.jpg
#   inflating: dataset2/test/Apples/r_40_100B.jpg
#   inflating: dataset2/test/Apples/r_41_100B.jpg
#   inflating: dataset2/test/Apples/r_42_100B.jpg
#   inflating: dataset2/test/Apples/r_43_100B.jpg
#   inflating: dataset2/test/Apples/r_44_100B.jpg
#   inflating: dataset2/test/Apples/r_45_100B.jpg
#   inflating: dataset2/test/Apples/r_46_100B.jpg
#   inflating: dataset2/test/Apples/r_47_100B.jpg
#   inflating: dataset2/test/Apples/r_48_100B.jpg
#   inflating: dataset2/test/Apples/r_49_100B.jpg
#   inflating: dataset2/test/Apples/r_4_100B.jpg
#   inflating: dataset2/test/Apples/r_50_100B.jpg
#   inflating: dataset2/test/Apples/r_51_100B.jpg
#   inflating: dataset2/test/Apples/r_52_100B.jpg
#   inflating: dataset2/test/Apples/r_53_100B.jpg
#   inflating: dataset2/test/Apples/r_54_100B.jpg
#   inflating: dataset2/test/Apples/r_55_100B.jpg
#   inflating: dataset2/test/Apples/r_56_100B.jpg
#   inflating: dataset2/test/Apples/r_57_100B.jpg
#   inflating: dataset2/test/Apples/r_58_100B.jpg
#   inflating: dataset2/test/Apples/r_59_100B.jpg
#   inflating: dataset2/test/Apples/r_5_100B.jpg
#   inflating: dataset2/test/Apples/r_60_100B.jpg
#   inflating: dataset2/test/Apples/r_61_100B.jpg
#   inflating: dataset2/test/Apples/r_62_100B.jpg
#   inflating: dataset2/test/Apples/r_63_100B.jpg
#   inflating: dataset2/test/Apples/r_64_100B.jpg
#   inflating: dataset2/test/Apples/r_65_100B.jpg
#   inflating: dataset2/test/Apples/r_66_100B.jpg
#   inflating: dataset2/test/Apples/r_67_100B.jpg
#   inflating: dataset2/test/Apples/r_68_100B.jpg
#   inflating: dataset2/test/Apples/r_69_100B.jpg
#   inflating: dataset2/test/Apples/r_6_100B.jpg
#   inflating: dataset2/test/Apples/r_70_100B.jpg
#   inflating: dataset2/test/Apples/r_71_100B.jpg
#   inflating: dataset2/test/Apples/r_72_100B.jpg
#   inflating: dataset2/test/Apples/r_73_100B.jpg
#   inflating: dataset2/test/Apples/r_74_100B.jpg
#   inflating: dataset2/test/Apples/r_75_100B.jpg
#   inflating: dataset2/test/Apples/r_76_100B.jpg
#   inflating: dataset2/test/Apples/r_77_100B.jpg
#   inflating: dataset2/test/Apples/r_78_100B.jpg
#   inflating: dataset2/test/Apples/r_79_100B.jpg
#   inflating: dataset2/test/Apples/r_7_100B.jpg
#   inflating: dataset2/test/Apples/r_80_100B.jpg
#   inflating: dataset2/test/Apples/r_81_100B.jpg
#   inflating: dataset2/test/Apples/r_82_100B.jpg
#   inflating: dataset2/test/Apples/r_83_100B.jpg
#   inflating: dataset2/test/Apples/r_84_100B.jpg
#   inflating: dataset2/test/Apples/r_85_100B.jpg
#   inflating: dataset2/test/Apples/r_86_100B.jpg
#   inflating: dataset2/test/Apples/r_87_100B.jpg
#   inflating: dataset2/test/Apples/r_88_100B.jpg
#   inflating: dataset2/test/Apples/r_89_100B.jpg
#   inflating: dataset2/test/Apples/r_8_100B.jpg
#   inflating: dataset2/test/Apples/r_90_100B.jpg
#   inflating: dataset2/test/Apples/r_91_100B.jpg
#   inflating: dataset2/test/Apples/r_92_100B.jpg
#   inflating: dataset2/test/Apples/r_93_100B.jpg
#   inflating: dataset2/test/Apples/r_94_100B.jpg
#   inflating: dataset2/test/Apples/r_95_100B.jpg
#   inflating: dataset2/test/Apples/r_96_100B.jpg
#   inflating: dataset2/test/Apples/r_97_100B.jpg
#   inflating: dataset2/test/Apples/r_98_100B.jpg
#   inflating: dataset2/test/Apples/r_99_100B.jpg
#   inflating: dataset2/test/Apples/r_9_100B.jpg
#   inflating: dataset2/test/Apples/321_100gC.jpg
#   inflating: dataset2/test/Apples/322_100gC.jpg
#   inflating: dataset2/test/Apples/323_100gC.jpg
#   inflating: dataset2/test/Apples/324_100gC.jpg
#   inflating: dataset2/test/Apples/325_100gC.jpg
#   inflating: dataset2/test/Apples/Golden_23_4.JPG
#   inflating: dataset2/test/Apples/Golden_24_1.JPG
#   inflating: dataset2/test/Apples/Golden_24_2.JPG
#   inflating: dataset2/test/Apples/Golden_24_3.JPG
#   inflating: dataset2/test/Apples/Golden_24_4.JPG
#   inflating: dataset2/test/Apples/Golden_25_1.JPG
#   inflating: dataset2/test/Apples/Golden_25_2.JPG
#   inflating: dataset2/test/Apples/Golden_25_3.JPG
#   inflating: dataset2/test/Apples/Golden_25_4.JPG
#   inflating: dataset2/test/Apples/Golden_18_3.JPG
#   inflating: dataset2/test/Apples/Golden_18_4.JPG
#   inflating: dataset2/test/Apples/Golden_19_1.JPG
#   inflating: dataset2/test/Apples/Golden_19_2.JPG
#   inflating: dataset2/test/Apples/Golden_19_3.JPG
#   inflating: dataset2/test/Apples/Golden_19_4.JPG
#   inflating: dataset2/test/Apples/Golden_20_1.JPG
#   inflating: dataset2/test/Apples/Golden_20_2.JPG
#   inflating: dataset2/test/Apples/Golden_20_3.JPG
#   inflating: dataset2/test/Apples/Golden_20_4.JPG
#   inflating: dataset2/test/Apples/Golden_21_1.JPG
#   inflating: dataset2/test/Apples/Golden_21_2.JPG
#   inflating: dataset2/test/Apples/Golden_21_3.JPG
#   inflating: dataset2/test/Apples/Golden_21_4.JPG
#   inflating: dataset2/test/Apples/Golden_22_1.JPG
#   inflating: dataset2/test/Apples/Golden_22_2.JPG
#   inflating: dataset2/test/Apples/Golden_22_3.JPG
#   inflating: dataset2/test/Apples/Golden_22_4.JPG
#   inflating: dataset2/test/Apples/Golden_23_1.JPG
#   inflating: dataset2/test/Apples/Golden_23_2.JPG
#   inflating: dataset2/test/Apples/Golden_23_3.JPG
#   inflating: dataset2/test/Apples/326_100gC.jpg
#   inflating: dataset2/test/Apples/327_100gC.jpg
#   inflating: dataset2/test/Apples/32_100gC.jpg
#   inflating: dataset2/test/Apples/33_100gC.jpg
#   inflating: dataset2/test/Apples/34_100gC.jpg
#   inflating: dataset2/test/Apples/35_100gC.jpg
#   inflating: dataset2/test/Apples/36_100gC.jpg
#   inflating: dataset2/test/Apples/37_100gC.jpg
#   inflating: dataset2/test/Apples/38_100gC.jpg
#   inflating: dataset2/test/Apples/39_100gC.jpg
#   inflating: dataset2/test/Apples/3_100gC.jpg
#   inflating: dataset2/test/Apples/40_100gC.jpg
#   inflating: dataset2/test/Apples/41_100gC.jpg
#   inflating: dataset2/test/Apples/42_100gC.jpg
#   inflating: dataset2/test/Apples/43_100gC.jpg
#   inflating: dataset2/test/Apples/44_100gC.jpg
#   inflating: dataset2/test/Apples/45_100gC.jpg
#   inflating: dataset2/test/Apples/46_100gC.jpg
#   inflating: dataset2/test/Apples/47_100gC.jpg
#   inflating: dataset2/test/Apples/48_100gC.jpg
#   inflating: dataset2/test/Apples/4_100gC.jpg
#   inflating: dataset2/test/Apples/52_100gC.jpg
#   inflating: dataset2/test/Apples/53_100gC.jpg
#   inflating: dataset2/test/Apples/54_100gC.jpg
#   inflating: dataset2/test/Apples/55_100gC.jpg
#   inflating: dataset2/test/Apples/59_100gC.jpg
#   inflating: dataset2/test/Apples/5_100gC.jpg
#   inflating: dataset2/test/Apples/60_100gC.jpg
#   inflating: dataset2/test/Apples/61_100gC.jpg
#   inflating: dataset2/test/Apples/62_100gC.jpg
#   inflating: dataset2/test/Apples/63_100gC.jpg
#   inflating: dataset2/test/Apples/64_100gC.jpg
#   inflating: dataset2/test/Apples/65_100gC.jpg
#   inflating: dataset2/test/Apples/66_100gC.jpg
#   inflating: dataset2/test/Apples/67_100gC.jpg
#   inflating: dataset2/test/Apples/68_100gC.jpg
#   inflating: dataset2/test/Apples/69_100gC.jpg
#   inflating: dataset2/test/Apples/6_100gC.jpg
#   inflating: dataset2/test/Apples/70_100gC.jpg
#   inflating: dataset2/test/Apples/71_100gC.jpg
#   inflating: dataset2/test/Apples/72_100gC.jpg
#   inflating: dataset2/test/Apples/73_100gC.jpg
#   inflating: dataset2/test/Apples/74_100gC.jpg
#   inflating: dataset2/test/Apples/75_100gC.jpg
#   inflating: dataset2/test/Apples/76_100gC.jpg
#   inflating: dataset2/test/Apples/77_100gC.jpg
#   inflating: dataset2/test/Apples/78_100gC.jpg
#   inflating: dataset2/test/Apples/79_100gC.jpg
#   inflating: dataset2/test/Apples/7_100gC.jpg
#   inflating: dataset2/test/Apples/80_100gC.jpg
#   inflating: dataset2/test/Apples/81_100gC.jpg
#   inflating: dataset2/test/Apples/82_100gC.jpg
#   inflating: dataset2/test/Apples/83_100gC.jpg
#   inflating: dataset2/test/Apples/84_100gC.jpg
#   inflating: dataset2/test/Apples/85_100gC.jpg
#   inflating: dataset2/test/Apples/86_100gC.jpg
#   inflating: dataset2/test/Apples/87_100gC.jpg
#   inflating: dataset2/test/Apples/88_100gC.jpg
#   inflating: dataset2/test/Apples/89_100gC.jpg
#   inflating: dataset2/test/Apples/8_100gC.jpg
#   inflating: dataset2/test/Apples/90_100gC.jpg
#   inflating: dataset2/test/Apples/91_100gC.jpg
#   inflating: dataset2/test/Apples/92_100gC.jpg
#   inflating: dataset2/test/Apples/93_100gC.jpg
#   inflating: dataset2/test/Apples/94_100gC.jpg
#   inflating: dataset2/test/Apples/95_100gC.jpg
#   inflating: dataset2/test/Apples/96_100gC.jpg
#   inflating: dataset2/test/Apples/97_100gC.jpg
#   inflating: dataset2/test/Apples/98_100gC.jpg
#   inflating: dataset2/test/Apples/99_100gC.jpg
#   inflating: dataset2/test/Apples/9_100gC.jpg
#   inflating: dataset2/test/Apples/r_321_100gC.jpg
#   inflating: dataset2/test/Apples/r_322_100gC.jpg
#   inflating: dataset2/test/Apples/r_323_100gC.jpg
#   inflating: dataset2/test/Apples/r_324_100gC.jpg
#   inflating: dataset2/test/Apples/r_325_100gC.jpg
#   inflating: dataset2/test/Apples/r_326_100gC.jpg
#   inflating: dataset2/test/Apples/r_327_100gC.jpg
#   inflating: dataset2/test/Apples/r_32_100gC.jpg
#   inflating: dataset2/test/Apples/r_33_100gC.jpg
#   inflating: dataset2/test/Apples/r_34_100gC.jpg
#   inflating: dataset2/test/Apples/r_35_100gC.jpg
#   inflating: dataset2/test/Apples/r_36_100gC.jpg
#   inflating: dataset2/test/Apples/r_37_100gC.jpg
#   inflating: dataset2/test/Apples/r_38_100gC.jpg
#   inflating: dataset2/test/Apples/r_39_100gC.jpg
#   inflating: dataset2/test/Apples/r_3_100gC.jpg
#   inflating: dataset2/test/Apples/r_40_100gC.jpg
#   inflating: dataset2/test/Apples/r_41_100gC.jpg
#   inflating: dataset2/test/Apples/r_42_100gC.jpg
#   inflating: dataset2/test/Apples/r_43_100gC.jpg
#   inflating: dataset2/test/Apples/r_44_100gC.jpg
#   inflating: dataset2/test/Apples/r_45_100gC.jpg
#   inflating: dataset2/test/Apples/r_46_100gC.jpg
#   inflating: dataset2/test/Apples/r_47_100gC.jpg
#   inflating: dataset2/test/Apples/r_48_100gC.jpg
#   inflating: dataset2/test/Apples/r_49_100gC.jpg
#   inflating: dataset2/test/Apples/r_4_100gC.jpg
#   inflating: dataset2/test/Apples/r_50_100gC.jpg
#   inflating: dataset2/test/Apples/r_51_100gC.jpg
#   inflating: dataset2/test/Apples/r_52_100gC.jpg
#   inflating: dataset2/test/Apples/r_53_100gC.jpg
#   inflating: dataset2/test/Apples/r_54_100gC.jpg
#   inflating: dataset2/test/Apples/r_55_100gC.jpg
#   inflating: dataset2/test/Apples/r_56_100gC.jpg
#   inflating: dataset2/test/Apples/r_57_100gC.jpg
#   inflating: dataset2/test/Apples/r_58_100gC.jpg
#   inflating: dataset2/test/Apples/r_59_100gC.jpg
#   inflating: dataset2/test/Apples/r_5_100gC.jpg
#   inflating: dataset2/test/Apples/r_60_100gC.jpg
#   inflating: dataset2/test/Apples/r_61_100gC.jpg
#   inflating: dataset2/test/Apples/r_62_100gC.jpg
#   inflating: dataset2/test/Apples/r_63_100gC.jpg
#   inflating: dataset2/test/Apples/r_64_100gC.jpg
#   inflating: dataset2/test/Apples/r_65_100gC.jpg
#   inflating: dataset2/test/Apples/r_66_100gC.jpg
#   inflating: dataset2/test/Apples/r_67_100gC.jpg
#   inflating: dataset2/test/Apples/r_68_100gC.jpg
#   inflating: dataset2/test/Apples/r_69_100gC.jpg
#   inflating: dataset2/test/Apples/r_6_100gC.jpg
#   inflating: dataset2/test/Apples/r_70_100gC.jpg
#   inflating: dataset2/test/Apples/r_71_100gC.jpg
#   inflating: dataset2/test/Apples/r_72_100gC.jpg
#   inflating: dataset2/test/Apples/r_73_100gC.jpg
#   inflating: dataset2/test/Apples/r_74_100gC.jpg
#   inflating: dataset2/test/Apples/r_75_100gC.jpg
#   inflating: dataset2/test/Apples/r_76_100gC.jpg
#   inflating: dataset2/test/Apples/r_77_100gC.jpg
#   inflating: dataset2/test/Apples/r_78_100gC.jpg
#   inflating: dataset2/test/Apples/r_79_100gC.jpg
#   inflating: dataset2/test/Apples/r_7_100gC.jpg
#   inflating: dataset2/test/Apples/r_80_100gC.jpg
#   inflating: dataset2/test/Apples/r_81_100gC.jpg
#   inflating: dataset2/test/Apples/r_82_100gC.jpg
#   inflating: dataset2/test/Apples/r_83_100gC.jpg
#   inflating: dataset2/test/Apples/r_84_100gC.jpg
#   inflating: dataset2/test/Apples/r_85_100gC.jpg
#   inflating: dataset2/test/Apples/r_86_100gC.jpg
#   inflating: dataset2/test/Apples/r_87_100gC.jpg
#   inflating: dataset2/test/Apples/r_88_100gC.jpg
#   inflating: dataset2/test/Apples/r_89_100gC.jpg
#   inflating: dataset2/test/Apples/r_8_100gC.jpg
#   inflating: dataset2/test/Apples/r_90_100gC.jpg
#   inflating: dataset2/test/Apples/r_91_100gC.jpg
#   inflating: dataset2/test/Apples/r_92_100gC.jpg
#   inflating: dataset2/test/Apples/r_93_100gC.jpg
#   inflating: dataset2/test/Apples/r_94_100gC.jpg
#   inflating: dataset2/test/Apples/r_95_100gC.jpg
#   inflating: dataset2/test/Apples/r_96_100gC.jpg
#   inflating: dataset2/test/Apples/r_97_100gC.jpg
#   inflating: dataset2/test/Apples/r_98_100gC.jpg
#   inflating: dataset2/test/Apples/r_99_100gC.jpg
#   inflating: dataset2/test/Apples/r_9_100gC.jpg
#   inflating: dataset2/test/Apples/44_100C.jpg
#   inflating: dataset2/test/Apples/45_100C.jpg
#   inflating: dataset2/test/Apples/46_100C.jpg
#   inflating: dataset2/test/Apples/47_100C.jpg
#   inflating: dataset2/test/Apples/48_100C.jpg
#   inflating: dataset2/test/Apples/49_100C.jpg
#   inflating: dataset2/test/Apples/4_100C.jpg
#   inflating: dataset2/test/Apples/52_100C.jpg
#   inflating: dataset2/test/Apples/53_100C.jpg
#   inflating: dataset2/test/Apples/54_100C.jpg
#   inflating: dataset2/test/Apples/55_100C.jpg
#   inflating: dataset2/test/Apples/56_100C.jpg
#   inflating: dataset2/test/Apples/5_100C.jpg
#   inflating: dataset2/test/Apples/60_100C.jpg
#   inflating: dataset2/test/Apples/61_100C.jpg
#   inflating: dataset2/test/Apples/62_100C.jpg
#   inflating: dataset2/test/Apples/63_100C.jpg
#   inflating: dataset2/test/Apples/64_100C.jpg
#   inflating: dataset2/test/Apples/65_100C.jpg
#   inflating: dataset2/test/Apples/66_100C.jpg
#   inflating: dataset2/test/Apples/67_100C.jpg
#   inflating: dataset2/test/Apples/68_100C.jpg
#   inflating: dataset2/test/Apples/69_100C.jpg
#   inflating: dataset2/test/Apples/6_100C.jpg
#   inflating: dataset2/test/Apples/70_100C.jpg
#   inflating: dataset2/test/Apples/71_100C.jpg
#   inflating: dataset2/test/Apples/72_100C.jpg
#   inflating: dataset2/test/Apples/73_100C.jpg
#   inflating: dataset2/test/Apples/74_100C.jpg
#   inflating: dataset2/test/Apples/75_100C.jpg
#   inflating: dataset2/test/Apples/76_100C.jpg
#   inflating: dataset2/test/Apples/77_100C.jpg
#   inflating: dataset2/test/Apples/78_100C.jpg
#   inflating: dataset2/test/Apples/79_100C.jpg
#   inflating: dataset2/test/Apples/7_100C.jpg
#   inflating: dataset2/test/Apples/80_100C.jpg
#   inflating: dataset2/test/Apples/81_100C.jpg
#   inflating: dataset2/test/Apples/82_100C.jpg
#   inflating: dataset2/test/Apples/83_100C.jpg
#   inflating: dataset2/test/Apples/84_100C.jpg
#   inflating: dataset2/test/Apples/85_100C.jpg
#   inflating: dataset2/test/Apples/86_100C.jpg
#   inflating: dataset2/test/Apples/87_100C.jpg
#   inflating: dataset2/test/Apples/88_100C.jpg
#   inflating: dataset2/test/Apples/89_100C.jpg
#   inflating: dataset2/test/Apples/8_100C.jpg
#   inflating: dataset2/test/Apples/90_100C.jpg
#   inflating: dataset2/test/Apples/91_100C.jpg
#   inflating: dataset2/test/Apples/92_100C.jpg
#   inflating: dataset2/test/Apples/93_100C.jpg
#   inflating: dataset2/test/Apples/94_100C.jpg
#   inflating: dataset2/test/Apples/95_100C.jpg
#   inflating: dataset2/test/Apples/96_100C.jpg
#   inflating: dataset2/test/Apples/97_100C.jpg
#   inflating: dataset2/test/Apples/98_100C.jpg
#   inflating: dataset2/test/Apples/99_100C.jpg
#   inflating: dataset2/test/Apples/9_100C.jpg
#   inflating: dataset2/test/Apples/r_321_100C.jpg
#   inflating: dataset2/test/Apples/r_322_100C.jpg
#   inflating: dataset2/test/Apples/r_323_100C.jpg
#   inflating: dataset2/test/Apples/r_324_100C.jpg
#   inflating: dataset2/test/Apples/r_325_100C.jpg
#   inflating: dataset2/test/Apples/r_326_100C.jpg
#   inflating: dataset2/test/Apples/r_327_100C.jpg
#   inflating: dataset2/test/Apples/r_32_100C.jpg
#   inflating: dataset2/test/Apples/r_33_100C.jpg
#   inflating: dataset2/test/Apples/r_34_100C.jpg
#   inflating: dataset2/test/Apples/r_35_100C.jpg
#   inflating: dataset2/test/Apples/r_36_100C.jpg
#   inflating: dataset2/test/Apples/r_37_100C.jpg
#   inflating: dataset2/test/Apples/r_38_100C.jpg
#   inflating: dataset2/test/Apples/r_39_100C.jpg
#   inflating: dataset2/test/Apples/r_3_100C.jpg
#   inflating: dataset2/test/Apples/r_40_100C.jpg
#   inflating: dataset2/test/Apples/r_41_100C.jpg
#   inflating: dataset2/test/Apples/r_42_100C.jpg
#   inflating: dataset2/test/Apples/r_43_100C.jpg
#   inflating: dataset2/test/Apples/r_44_100C.jpg
#   inflating: dataset2/test/Apples/r_45_100C.jpg
#   inflating: dataset2/test/Apples/r_46_100C.jpg
# ...
#   inflating: dataset2/validation/Apples/r_148_100C.jpg
#   inflating: dataset2/validation/Apples/r_149_100C.jpg
#   inflating: dataset2/validation/Apples/r_150_100C.jpg
#   inflating: dataset2/validation/Apples/r_151_100C.jpg
#   inflating: dataset2/validation/Apples/r_152_100C.jpg
#   inflating: dataset2/validation/Apples/r_153_100C.jpg
#   inflating: dataset2/validation/Apples/r_154_100C.jpg
#   inflating: dataset2/validation/Apples/r_191_100C.jpg
#   inflating: dataset2/validation/Apples/r_192_100C.jpg
#   inflating: dataset2/validation/Apples/r_193_100C.jpg
#   inflating: dataset2/validation/Apples/r_195_100C.jpg
#   inflating: dataset2/validation/Apples/r_196_100C.jpg
#   inflating: dataset2/validation/Apples/r_197_100C.jpg
#   inflating: dataset2/validation/Apples/r_198_100C.jpg
#   inflating: dataset2/validation/Apples/r_199_100C.jpg
#   inflating: dataset2/validation/Apples/r_200_100C.jpg
#   inflating: dataset2/validation/Apples/r_201_100C.jpg
#   inflating: dataset2/validation/Apples/r_202_100C.jpg
#   inflating: dataset2/validation/Apples/r_203_100C.jpg
#   inflating: dataset2/validation/Apples/r_204_100C.jpg
#   inflating: dataset2/validation/Apples/r_205_100C.jpg
#   inflating: dataset2/validation/Apples/r_206_100C.jpg
#   inflating: dataset2/validation/Apples/r_207_100C.jpg
#   inflating: dataset2/validation/Apples/r_208_100C.jpg
#   inflating: dataset2/validation/Apples/r_22_100C.jpg
#   inflating: dataset2/validation/Apples/r_23_100C.jpg
#   inflating: dataset2/validation/Apples/r_24_100C.jpg
#   inflating: dataset2/validation/Apples/r_250_100C.jpg
#   inflating: dataset2/validation/Apples/r_251_100C.jpg
#   inflating: dataset2/validation/Apples/r_252_100C.jpg
#   inflating: dataset2/validation/Apples/r_253_100C.jpg
#   inflating: dataset2/validation/Apples/r_254_100C.jpg
#   inflating: dataset2/validation/Apples/r_255_100C.jpg
#   inflating: dataset2/validation/Apples/r_256_100C.jpg
#   inflating: dataset2/validation/Apples/r_257_100C.jpg
#   inflating: dataset2/validation/Apples/r_258_100C.jpg
#   inflating: dataset2/validation/Apples/r_259_100C.jpg
#   inflating: dataset2/validation/Apples/r_25_100C.jpg
#   inflating: dataset2/validation/Apples/r_260_100C.jpg
#   inflating: dataset2/validation/Apples/r_261_100C.jpg
#   inflating: dataset2/validation/Apples/r_262_100C.jpg
#   inflating: dataset2/validation/Apples/r_263_100C.jpg
#   inflating: dataset2/validation/Apples/r_264_100C.jpg
#   inflating: dataset2/validation/Apples/r_265_100C.jpg
#   inflating: dataset2/validation/Apples/r_266_100C.jpg
#   inflating: dataset2/validation/Apples/r_267_100C.jpg
#   inflating: dataset2/validation/Apples/r_26_100C.jpg
#   inflating: dataset2/validation/Apples/r_27_100C.jpg
#   inflating: dataset2/validation/Apples/r_28_100C.jpg
#   inflating: dataset2/validation/Apples/r_295_100C.jpg
#   inflating: dataset2/validation/Apples/r_296_100C.jpg
#   inflating: dataset2/validation/Apples/r_297_100C.jpg
#   inflating: dataset2/validation/Apples/r_298_100C.jpg
#   inflating: dataset2/validation/Apples/r_299_100C.jpg
#   inflating: dataset2/validation/Apples/r_29_100C.jpg
#   inflating: dataset2/validation/Apples/r_300_100C.jpg
#   inflating: dataset2/validation/Apples/r_301_100C.jpg
#   inflating: dataset2/validation/Apples/r_302_100C.jpg
#   inflating: dataset2/validation/Apples/r_303_100C.jpg
#   inflating: dataset2/validation/Apples/r_30_100C.jpg
#   inflating: dataset2/validation/Apples/r_319_100C.jpg
#   inflating: dataset2/validation/Apples/r_31_100C.jpg
#   inflating: dataset2/validation/Apples/r_320_100C.jpg
#   inflating: dataset2/validation/Apples/107_100C.jpg
#   inflating: dataset2/validation/Apples/108_100C.jpg
#   inflating: dataset2/validation/Apples/109_100C.jpg
#   inflating: dataset2/validation/Apples/110_100C.jpg
#   inflating: dataset2/validation/Apples/111_100C.jpg
#   inflating: dataset2/validation/Apples/112_100C.jpg
#   inflating: dataset2/validation/Apples/113_100C.jpg
#   inflating: dataset2/validation/Apples/114_100C.jpg
#   inflating: dataset2/validation/Apples/115_100C.jpg
#   inflating: dataset2/validation/Apples/116_100C.jpg
#   inflating: dataset2/validation/Apples/117_100C.jpg
#   inflating: dataset2/validation/Apples/118_100C.jpg
#   inflating: dataset2/validation/Apples/119_100C.jpg
#   inflating: dataset2/validation/Apples/120_100C.jpg
#   inflating: dataset2/validation/Apples/121_100C.jpg
#   inflating: dataset2/validation/Apples/122_100C.jpg
#   inflating: dataset2/validation/Apples/123_100C.jpg
#   inflating: dataset2/validation/Apples/124_100C.jpg
#   inflating: dataset2/validation/Apples/49_100gC.jpg
#   inflating: dataset2/validation/Apples/50_100gC.jpg
#   inflating: dataset2/validation/Apples/51_100gC.jpg
#   inflating: dataset2/validation/Apples/57_100gC.jpg
#   inflating: dataset2/validation/Apples/58_100gC.jpg
#   inflating: dataset2/validation/Apples/50_100C.jpg
#   inflating: dataset2/validation/Apples/51_100C.jpg
#   inflating: dataset2/validation/Apples/57_100C.jpg
#   inflating: dataset2/validation/Apples/58_100C.jpg
#   inflating: dataset2/validation/Apples/59_100C.jpg
#   inflating: dataset2/validation/Apples/11b.jpg
#   inflating: dataset2/validation/Apples/20b.jpg
#   inflating: dataset2/validation/Apples/11br1.jpg
#   inflating: dataset2/validation/Apples/17br2.jpg
#   inflating: dataset2/validation/Apples/10br1.jpg
#   inflating: dataset2/validation/Apples/16b.jpg
#   inflating: dataset2/validation/Apples/11br3.jpg
#   inflating: dataset2/validation/Apples/19br2.jpg
#   inflating: dataset2/validation/Apples/37br3.jpg
#   inflating: dataset2/validation/Apples/31b.jpg
#   inflating: dataset2/validation/Apples/16br2.jpg
#   inflating: dataset2/validation/Apples/13b.jpg
#   inflating: dataset2/validation/Apples/13br1.jpg
#   inflating: dataset2/validation/Apples/17br1.jpg
#   inflating: dataset2/validation/Apples/28br2.jpg
#   inflating: dataset2/validation/Apples/12b.jpg
#   inflating: dataset2/validation/Apples/34b.jpg
#   inflating: dataset2/validation/Apples/18br3.jpg
#   inflating: dataset2/validation/Apples/18br2.jpg
#   inflating: dataset2/validation/Apples/36br3.jpg
#   inflating: dataset2/validation/Apples/13br3.jpg
#   inflating: dataset2/validation/Apples/14br3.jpg
#   inflating: dataset2/validation/Apples/11br2.jpg
#   inflating: dataset2/validation/Apples/14br1.jpg
#   inflating: dataset2/validation/Apples/27br1.jpg
#   inflating: dataset2/validation/Apples/10b.jpg
#   inflating: dataset2/validation/Apples/17b.jpg
#   inflating: dataset2/validation/Apples/16br3.jpg
#   inflating: dataset2/validation/Apples/10br2.jpg
#   inflating: dataset2/validation/Apples/16br1.jpg
#   inflating: dataset2/validation/Apples/10br3.jpg
#   inflating: dataset2/validation/Apples/12br2.jpg
#   inflating: dataset2/validation/Apples/15br2.jpg
#   inflating: dataset2/validation/Apples/15b.jpg
#   inflating: dataset2/validation/Apples/12br1.jpg
#   inflating: dataset2/validation/Apples/12br3.jpg
#   inflating: dataset2/validation/Apples/14br2.jpg
#   inflating: dataset2/validation/Apples/15br3.jpg
#   inflating: dataset2/validation/Apples/15br1.jpg
#   inflating: dataset2/validation/Apples/17br3.jpg
#   inflating: dataset2/validation/Apples/13br2.jpg
#   inflating: dataset2/validation/Apples/18b.jpg
#   inflating: dataset2/validation/Apples/18br1.jpg
#   inflating: dataset2/validation/Apples/34br2.jpg
#   inflating: dataset2/validation/Apples/14b.jpg
#   inflating: dataset2/validation/Apples/30br2.jpg
#   inflating: dataset2/validation/Apples/r_232_100g.jpg
#   inflating: dataset2/validation/Apples/r_151_100.jpg
#   inflating: dataset2/validation/Apples/135_100gB.jpg
#   inflating: dataset2/validation/Apples/141_100gB.jpg
#   inflating: dataset2/validation/Apples/293_100gB.jpg
#   inflating: dataset2/validation/Apples/r_194_100C.jpg
#    creating: dataset2/validation/notApples/
#   inflating: dataset2/validation/notApples/10_100bb.jpg
#   inflating: dataset2/validation/notApples/11_100bb.jpg
#   inflating: dataset2/validation/notApples/hqdefault.jpg
#   inflating: dataset2/validation/notApples/35_100bb.jpg
#   inflating: dataset2/validation/notApples/37_100bb.jpg
#   inflating: dataset2/validation/notApples/7_100bb.jpg
#   inflating: dataset2/validation/notApples/8_100bb.jpg
#   inflating: dataset2/validation/notApples/9_100bb.jpg
#   inflating: dataset2/validation/notApples/ft_training_with_epoch_100.png
#   inflating: dataset2/validation/notApples/image1.jpg
#    creating: dataset2/validation/notApples/new folder/
#   inflating: dataset2/validation/notApples/new folder/image14a.jpg
#   inflating: dataset2/validation/notApples/new folder/guarantor letter.jpg
#   inflating: dataset2/validation/notApples/new folder/first sitting result.jpg
#   inflating: dataset2/validation/notApples/new folder/jamb letter.jpg
#   inflating: dataset2/validation/notApples/new folder/resized2.jpg
#   inflating: dataset2/validation/notApples/new folder/resized3.jpg
#   inflating: dataset2/validation/notApples/new folder/resized4.jpg
#   inflating: dataset2/validation/notApples/new folder/IMG-20180828-WA0008.jpg
#   inflating: dataset2/validation/notApples/new folder/image26.jpg
#   inflating: dataset2/validation/notApples/new folder/resized5.jpg
#   inflating: dataset2/validation/notApples/new folder/resized6.jpg
#   inflating: dataset2/validation/notApples/new folder/resized7.jpg
#   inflating: dataset2/validation/notApples/new folder/IMG_20181006_111315.jpg
#   inflating: dataset2/validation/notApples/new folder/IMG_20181006_111323.jpg
#   inflating: dataset2/validation/notApples/new folder/image1.jpg
#   inflating: dataset2/validation/notApples/new folder/Image2.jpg
#   inflating: dataset2/validation/notApples/new folder/image3.jpg
#   inflating: dataset2/validation/notApples/new folder/image4.jpg
#   inflating: dataset2/validation/notApples/new folder/image5.jpg
#   inflating: dataset2/validation/notApples/new folder/image7.jpg
#   inflating: dataset2/validation/notApples/new folder/image11.jpg
#   inflating: dataset2/validation/notApples/new folder/image8.jpg
#   inflating: dataset2/validation/notApples/new folder/image9.jpg
#   inflating: dataset2/validation/notApples/new folder/image10.jpg
#   inflating: dataset2/validation/notApples/new folder/resized8.jpg
#   inflating: dataset2/validation/notApples/new folder/resized9.jpg
#   inflating: dataset2/validation/notApples/new folder/image18.jpg
#   inflating: dataset2/validation/notApples/new folder/image14.jpg
#   inflating: dataset2/validation/notApples/new folder/image16.jpg
#   inflating: dataset2/validation/notApples/new folder/image17.jpg
#   inflating: dataset2/validation/notApples/new folder/image24.jpg
#   inflating: dataset2/validation/notApples/new folder/image19.jpg
#   inflating: dataset2/validation/notApples/new folder/image22.jpg
#   inflating: dataset2/validation/notApples/new folder/image20.jpg
#   inflating: dataset2/validation/notApples/new folder/image21.jpg
#   inflating: dataset2/validation/notApples/new folder/image23.jpg
#   inflating: dataset2/validation/notApples/new folder/resized10.jpg
#   inflating: dataset2/validation/notApples/new folder/image12.jpg
#   inflating: dataset2/validation/notApples/new folder/waec certificate.jpg
#   inflating: dataset2/validation/notApples/new folder/resized12.jpg
#   inflating: dataset2/validation/notApples/new folder/acceptance letter.jpg
#   inflating: dataset2/validation/notApples/new folder/image13.jpg
#   inflating: dataset2/validation/notApples/new folder/resized15.jpg
#   inflating: dataset2/validation/notApples/new folder/affidavit of good conduct.jpg
#   inflating: dataset2/validation/notApples/new folder/affidavit for non-membership of secret cult.jpg
#   inflating: dataset2/validation/notApples/new folder/resized18.jpg
#   inflating: dataset2/validation/notApples/new folder/resized19.jpg
#   inflating: dataset2/validation/notApples/new folder/local gov id.jpg
#   inflating: dataset2/validation/notApples/new folder/resized21.jpg
#   inflating: dataset2/validation/notApples/new folder/image15.jpg
#   inflating: dataset2/validation/notApples/new folder/birth certificate.jpg
#   inflating: dataset2/validation/notApples/new folder/resized23.jpg
#   inflating: dataset2/validation/notApples/new folder/resized24.jpg
#   inflating: dataset2/validation/notApples/new folder/image6.jpg
#   inflating: dataset2/validation/notApples/14_100a.jpg
#   inflating: dataset2/validation/notApples/15_100a.jpg
#   inflating: dataset2/validation/notApples/16_100a.jpg
#   inflating: dataset2/validation/notApples/17_100a.jpg
#   inflating: dataset2/validation/notApples/18_100a.jpg
#   inflating: dataset2/validation/notApples/19_100a.jpg
#   inflating: dataset2/validation/notApples/20_100a.jpg
#   inflating: dataset2/validation/notApples/21_100a.jpg
#   inflating: dataset2/validation/notApples/14_100oo.jpg
#   inflating: dataset2/validation/notApples/15_100oo.jpg
#   inflating: dataset2/validation/notApples/16_100oo.jpg
#   inflating: dataset2/validation/notApples/17_100oo.jpg
#   inflating: dataset2/validation/notApples/18_100oo.jpg
#   inflating: dataset2/validation/notApples/19_100oo.jpg
#   inflating: dataset2/validation/notApples/20_100oo.jpg
#   inflating: dataset2/validation/notApples/21_100oo.jpg
#   inflating: dataset2/validation/notApples/10_100c.jpg
#   inflating: dataset2/validation/notApples/11_100c.jpg
#   inflating: dataset2/validation/notApples/12_100c.jpg
#   inflating: dataset2/validation/notApples/13_100c.jpg
#   inflating: dataset2/validation/notApples/7_100c.jpg
#   inflating: dataset2/validation/notApples/8_100c.jpg
#   inflating: dataset2/validation/notApples/9_100c.jpg
#   inflating: dataset2/validation/notApples/12_100cl.jpg
#   inflating: dataset2/validation/notApples/13_100cl.jpg
#   inflating: dataset2/validation/notApples/14_100cl.jpg
#   inflating: dataset2/validation/notApples/15_100cl.jpg
#   inflating: dataset2/validation/notApples/16_100cl.jpg
#   inflating: dataset2/validation/notApples/17_100cl.jpg
#   inflating: dataset2/validation/notApples/16_100p.jpg
#   inflating: dataset2/validation/notApples/17_100p.jpg
#   inflating: dataset2/validation/notApples/18_100p.jpg
#   inflating: dataset2/validation/notApples/19_100p.jpg
#   inflating: dataset2/validation/notApples/20_100p.jpg
#   inflating: dataset2/validation/notApples/21_100m.jpg
#   inflating: dataset2/validation/notApples/22_100m.jpg
#   inflating: dataset2/validation/notApples/23_100m.jpg
#   inflating: dataset2/validation/notApples/24_100m.jpg
#   inflating: dataset2/validation/notApples/25_100m.jpg
#   inflating: dataset2/validation/notApples/26_100m.jpg
#   inflating: dataset2/validation/notApples/27_100m.jpg
#   inflating: dataset2/validation/notApples/13_100t.jpg
#   inflating: dataset2/validation/notApples/14_100t.jpg
#   inflating: dataset2/validation/notApples/15_100t.jpg
#   inflating: dataset2/validation/notApples/16_100t.jpg
#   inflating: dataset2/validation/notApples/17_100t.jpg
#   inflating: dataset2/validation/notApples/18_100t.jpg
#   inflating: dataset2/validation/notApples/19_100t.jpg
#   inflating: dataset2/validation/notApples/20_100t.jpg
#   inflating: dataset2/validation/notApples/21_100t.jpg
#   inflating: dataset2/validation/notApples/10_100pi.jpg
#   inflating: dataset2/validation/notApples/11_100pi.jpg
#   inflating: dataset2/validation/notApples/14_100pi.jpg
#   inflating: dataset2/validation/notApples/19_100pi.jpg
#   inflating: dataset2/validation/notApples/20_100pi.jpg
#   inflating: dataset2/validation/notApples/21_100pi.jpg
#   inflating: dataset2/validation/notApples/23_100pi.jpg
#   inflating: dataset2/validation/notApples/nft_train_and_val_acc_graph.png
#   inflating: dataset2/validation/notApples/nft_train_and_val_loss_graph.png
#   inflating: dataset2/validation/notApples/nft_training_with_epoch_30.png
#   inflating: dataset2/validation/notApples/Ofada-Rice-and-Stew.jpg
#   inflating: dataset2/validation/notApples/raw ofada rice.jpg

# %%
# Run it to obtain reproducible results across machines (from keras.io)

from __future__ import print_function
import numpy as np
import tensorflow as tf
import random as rn
import os
os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(42)
rn.seed(12345)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)

from keras import backend as K
tf.set_random_seed(1234)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)
# Out:
# Using TensorFlow backend.

# %%
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.applications import ResNet50
from keras import models
from keras import layers
from keras import optimizers
#from keras.applications.vgg16 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import os
import numpy as np

# get train directory
train_dir = os.path.join('dataset2', 'train')
validation_dir = os.path.join('dataset2', 'validation')
test_dir = os.path.join('dataset2', 'test')

# initialize the convolutional base
inception_base = ResNet50(weights='imagenet',
                 include_top=False)

# Construct the model
"""
model = models.Sequential()
model.add(conv_base)
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(3, activation='relu'))
"""
#print(model.summary())
x = inception_base.output
x = layers.GlobalAveragePooling2D()(x)
# add a fully-connected layer
x = layers.Dense(512, activation='relu')(x)
# and a fully connected output/classification layer
predictions = layers.Dense(2, activation='softmax')(x)
# create the full network so we can train on it
inception_transfer = models.Model(inputs=inception_base.input, outputs=predictions)

# note old learning rate = 2e-5
inception_transfer.compile(loss='categorical_crossentropy',
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])
# create a data augmentation generator for the train and text dataset

train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

#train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=15,
    class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
    validation_dir,
    target_size=(224,224),
    batch_size=15,
    class_mode='categorical')

# note old epochs = 30
history = inception_transfer.fit_generator(
    train_generator,
    epochs=100,
    steps_per_epoch=25,
    shuffle=True,
    verbose=1,
    validation_data=validation_generator, validation_steps=25)

inception_transfer.save('apple_grading_model9.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras_applications/resnet50.py:265: UserWarning: The output shape of `ResNet50(include_top=False)` has been changed since Keras 2.2.0.
#   warnings.warn('The output shape of `ResNet50(include_top=False)` '
# Found 2155 images belonging to 2 classes.
# Found 1132 images belonging to 2 classes.
# Epoch 1/100
# 25/25 [==============================] - 30s 1s/step - loss: 0.3486 - acc: 0.8720 - val_loss: 0.3381 - val_acc: 0.8907
# Epoch 2/100
# 25/25 [==============================] - 14s 576ms/step - loss: 0.1126 - acc: 0.9680 - val_loss: 0.3100 - val_acc: 0.8800
# Epoch 3/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.1114 - acc: 0.9680 - val_loss: 0.2513 - val_acc: 0.9013
# Epoch 4/100
# 25/25 [==============================] - 15s 597ms/step - loss: 0.1479 - acc: 0.9440 - val_loss: 0.2401 - val_acc: 0.8828
# Epoch 5/100
# 25/25 [==============================] - 15s 589ms/step - loss: 0.0856 - acc: 0.9707 - val_loss: 0.2211 - val_acc: 0.8933
# Epoch 6/100
# 25/25 [==============================] - 16s 624ms/step - loss: 0.0566 - acc: 0.9840 - val_loss: 0.1715 - val_acc: 0.9147
# Epoch 7/100
# 25/25 [==============================] - 15s 589ms/step - loss: 0.0789 - acc: 0.9707 - val_loss: 0.1710 - val_acc: 0.9019
# Epoch 8/100
# 25/25 [==============================] - 14s 577ms/step - loss: 0.0893 - acc: 0.9707 - val_loss: 0.1429 - val_acc: 0.9413
# Epoch 9/100
# 25/25 [==============================] - 15s 583ms/step - loss: 0.0525 - acc: 0.9813 - val_loss: 0.1703 - val_acc: 0.9227
# Epoch 10/100
# 25/25 [==============================] - 15s 580ms/step - loss: 0.1049 - acc: 0.9520 - val_loss: 0.1634 - val_acc: 0.9591
# Epoch 11/100
# 25/25 [==============================] - 14s 579ms/step - loss: 0.0762 - acc: 0.9627 - val_loss: 0.1141 - val_acc: 0.9653
# Epoch 12/100
# 25/25 [==============================] - 14s 577ms/step - loss: 0.0461 - acc: 0.9867 - val_loss: 0.1193 - val_acc: 0.9573
# Epoch 13/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0612 - acc: 0.9760 - val_loss: 0.1150 - val_acc: 0.9564
# Epoch 14/100
# 25/25 [==============================] - 15s 582ms/step - loss: 0.0555 - acc: 0.9760 - val_loss: 0.1112 - val_acc: 0.9600
# Epoch 15/100
# 25/25 [==============================] - 15s 583ms/step - loss: 0.0455 - acc: 0.9867 - val_loss: 0.0652 - val_acc: 0.9680
# Epoch 16/100
# 25/25 [==============================] - 14s 575ms/step - loss: 0.0463 - acc: 0.9787 - val_loss: 0.0795 - val_acc: 0.9646
# Epoch 17/100
# 25/25 [==============================] - 14s 578ms/step - loss: 0.0383 - acc: 0.9920 - val_loss: 0.0558 - val_acc: 0.9707
# Epoch 18/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0354 - acc: 0.9867 - val_loss: 0.0694 - val_acc: 0.9813
# Epoch 19/100
# 25/25 [==============================] - 15s 583ms/step - loss: 0.0387 - acc: 0.9867 - val_loss: 0.0515 - val_acc: 0.9782
# Epoch 20/100
# 25/25 [==============================] - 15s 593ms/step - loss: 0.0295 - acc: 0.9947 - val_loss: 0.0939 - val_acc: 0.9600
# Epoch 21/100
# 25/25 [==============================] - 15s 592ms/step - loss: 0.0313 - acc: 0.9867 - val_loss: 0.0345 - val_acc: 0.9920
# Epoch 22/100
# 25/25 [==============================] - 14s 577ms/step - loss: 0.0375 - acc: 0.9920 - val_loss: 0.0558 - val_acc: 0.9755
# Epoch 23/100
# 25/25 [==============================] - 15s 586ms/step - loss: 0.0341 - acc: 0.9893 - val_loss: 0.0521 - val_acc: 0.9813
# Epoch 24/100
# 25/25 [==============================] - 15s 581ms/step - loss: 0.0415 - acc: 0.9867 - val_loss: 0.0514 - val_acc: 0.9840
# Epoch 25/100
# 25/25 [==============================] - 14s 576ms/step - loss: 0.0280 - acc: 0.9920 - val_loss: 0.0599 - val_acc: 0.9728
# Epoch 26/100
# 25/25 [==============================] - 15s 581ms/step - loss: 0.0288 - acc: 0.9947 - val_loss: 0.0592 - val_acc: 0.9787
# Epoch 27/100
# 25/25 [==============================] - 15s 582ms/step - loss: 0.0236 - acc: 0.9947 - val_loss: 0.0432 - val_acc: 0.9867
# Epoch 28/100
# 25/25 [==============================] - 15s 590ms/step - loss: 0.0215 - acc: 0.9947 - val_loss: 0.0301 - val_acc: 0.9891
# Epoch 29/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0198 - acc: 0.9947 - val_loss: 0.0424 - val_acc: 0.9813
# Epoch 30/100
# 25/25 [==============================] - 15s 584ms/step - loss: 0.0212 - acc: 0.9947 - val_loss: 0.0425 - val_acc: 0.9867
# Epoch 31/100
# 25/25 [==============================] - 14s 576ms/step - loss: 0.0335 - acc: 0.9893 - val_loss: 0.0420 - val_acc: 0.9809
# Epoch 32/100
# 25/25 [==============================] - 15s 585ms/step - loss: 0.0244 - acc: 0.9947 - val_loss: 0.0418 - val_acc: 0.9867
# Epoch 33/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0194 - acc: 0.9973 - val_loss: 0.0227 - val_acc: 0.9947
# Epoch 34/100
# 25/25 [==============================] - 15s 583ms/step - loss: 0.0166 - acc: 0.9973 - val_loss: 0.0334 - val_acc: 0.9918
# Epoch 35/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0206 - acc: 0.9973 - val_loss: 0.0289 - val_acc: 0.9920
# Epoch 36/100
# 25/25 [==============================] - 14s 578ms/step - loss: 0.0123 - acc: 1.0000 - val_loss: 0.0148 - val_acc: 1.0000
# Epoch 37/100
# 25/25 [==============================] - 14s 576ms/step - loss: 0.0144 - acc: 0.9973 - val_loss: 0.0356 - val_acc: 0.9837
# Epoch 38/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0207 - acc: 0.9947 - val_loss: 0.0249 - val_acc: 0.9920
# Epoch 39/100
# 25/25 [==============================] - 15s 580ms/step - loss: 0.0137 - acc: 0.9973 - val_loss: 0.0335 - val_acc: 0.9867
# Epoch 40/100
# 25/25 [==============================] - 14s 580ms/step - loss: 0.0198 - acc: 0.9893 - val_loss: 0.0449 - val_acc: 0.9864
# Epoch 41/100
# 25/25 [==============================] - 14s 580ms/step - loss: 0.0104 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9973
# Epoch 42/100
# 25/25 [==============================] - 15s 584ms/step - loss: 0.0160 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 0.9973
# Epoch 43/100
# 25/25 [==============================] - 14s 576ms/step - loss: 0.0180 - acc: 0.9973 - val_loss: 0.0171 - val_acc: 0.9918
# Epoch 44/100
# 25/25 [==============================] - 14s 575ms/step - loss: 0.0139 - acc: 1.0000 - val_loss: 0.0235 - val_acc: 0.9947
# Epoch 45/100
# 25/25 [==============================] - 15s 587ms/step - loss: 0.0132 - acc: 1.0000 - val_loss: 0.0207 - val_acc: 0.9947
# Epoch 46/100
# 25/25 [==============================] - 14s 577ms/step - loss: 0.0114 - acc: 1.0000 - val_loss: 0.0224 - val_acc: 0.9946
# Epoch 47/100
# 25/25 [==============================] - 14s 575ms/step - loss: 0.0135 - acc: 0.9973 - val_loss: 0.0219 - val_acc: 0.9947
# Epoch 48/100
# 25/25 [==============================] - 15s 580ms/step - loss: 0.0090 - acc: 0.9973 - val_loss: 0.0245 - val_acc: 0.9947
# Epoch 49/100
# 25/25 [==============================] - 15s 580ms/step - loss: 0.0183 - acc: 0.9947 - val_loss: 0.0193 - val_acc: 0.9973
# Epoch 50/100
# 25/25 [==============================] - 14s 578ms/step - loss: 0.0130 - acc: 1.0000 - val_loss: 0.0192 - val_acc: 0.9973
# Epoch 51/100
# 25/25 [==============================] - 15s 582ms/step - loss: 0.0109 - acc: 1.0000 - val_loss: 0.0090 - val_acc: 1.0000
# Epoch 52/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0126 - acc: 0.9947 - val_loss: 0.0270 - val_acc: 0.9918
# Epoch 53/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0129 - val_acc: 1.0000
# Epoch 54/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0115 - acc: 0.9973 - val_loss: 0.0206 - val_acc: 0.9973
# Epoch 55/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0150 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9946
# Epoch 56/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0079 - acc: 1.0000 - val_loss: 0.0144 - val_acc: 0.9973
# Epoch 57/100
# 25/25 [==============================] - 14s 575ms/step - loss: 0.0109 - acc: 0.9973 - val_loss: 0.0195 - val_acc: 0.9947
# Epoch 58/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0142 - acc: 1.0000 - val_loss: 0.0141 - val_acc: 1.0000
# Epoch 59/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0089 - acc: 1.0000 - val_loss: 0.0123 - val_acc: 0.9973
# Epoch 60/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0099 - acc: 1.0000 - val_loss: 0.0219 - val_acc: 0.9947
# Epoch 61/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0062 - acc: 1.0000 - val_loss: 0.0160 - val_acc: 0.9973
# Epoch 62/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9973
# Epoch 63/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0080 - acc: 1.0000 - val_loss: 0.0125 - val_acc: 0.9973
# Epoch 64/100
# 25/25 [==============================] - 14s 565ms/step - loss: 0.0096 - acc: 1.0000 - val_loss: 0.0177 - val_acc: 0.9973
# Epoch 65/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0111 - acc: 0.9973 - val_loss: 0.0102 - val_acc: 1.0000
# Epoch 66/100
# 25/25 [==============================] - 14s 569ms/step - loss: 0.0076 - acc: 1.0000 - val_loss: 0.0276 - val_acc: 0.9920
# Epoch 67/100
# 25/25 [==============================] - 14s 568ms/step - loss: 0.0085 - acc: 0.9973 - val_loss: 0.0080 - val_acc: 1.0000
# Epoch 68/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0119 - val_acc: 0.9973
# Epoch 69/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0064 - acc: 1.0000 - val_loss: 0.0194 - val_acc: 0.9947
# Epoch 70/100
# 25/25 [==============================] - 14s 567ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0068 - val_acc: 1.0000
# Epoch 71/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0051 - val_acc: 1.0000
# Epoch 72/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0131 - acc: 0.9947 - val_loss: 0.0194 - val_acc: 0.9947
# Epoch 73/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0052 - acc: 1.0000 - val_loss: 0.0104 - val_acc: 0.9973
# Epoch 74/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0148 - val_acc: 0.9973
# Epoch 75/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0082 - val_acc: 1.0000
# Epoch 76/100
# 25/25 [==============================] - 14s 569ms/step - loss: 0.0077 - acc: 1.0000 - val_loss: 0.0126 - val_acc: 0.9946
# Epoch 77/100
# 25/25 [==============================] - 14s 577ms/step - loss: 0.0058 - acc: 1.0000 - val_loss: 0.0140 - val_acc: 0.9973
# Epoch 78/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0147 - val_acc: 0.9947
# Epoch 79/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0057 - val_acc: 1.0000
# Epoch 80/100
# 25/25 [==============================] - 14s 568ms/step - loss: 0.0128 - acc: 0.9947 - val_loss: 0.0120 - val_acc: 0.9973
# Epoch 81/100
# 25/25 [==============================] - 14s 568ms/step - loss: 0.0045 - acc: 1.0000 - val_loss: 0.0149 - val_acc: 0.9947
# Epoch 82/100
# 25/25 [==============================] - 14s 570ms/step - loss: 0.0051 - acc: 1.0000 - val_loss: 0.0060 - val_acc: 1.0000
# Epoch 83/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0065 - acc: 1.0000 - val_loss: 0.0055 - val_acc: 1.0000
# Epoch 84/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0080 - acc: 0.9973 - val_loss: 0.0104 - val_acc: 0.9973
# Epoch 85/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0047 - acc: 1.0000 - val_loss: 0.0149 - val_acc: 0.9947
# Epoch 86/100
# 25/25 [==============================] - 14s 569ms/step - loss: 0.0044 - acc: 1.0000 - val_loss: 0.0109 - val_acc: 0.9973
# Epoch 87/100
# 25/25 [==============================] - 14s 569ms/step - loss: 0.0053 - acc: 1.0000 - val_loss: 0.0090 - val_acc: 0.9973
# Epoch 88/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0049 - acc: 1.0000 - val_loss: 0.0034 - val_acc: 1.0000
# Epoch 89/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0055 - acc: 1.0000 - val_loss: 0.0184 - val_acc: 0.9918
# Epoch 90/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0079 - acc: 0.9973 - val_loss: 0.0112 - val_acc: 0.9973
# Epoch 91/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0061 - acc: 0.9973 - val_loss: 0.0058 - val_acc: 1.0000
# Epoch 92/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0042 - acc: 1.0000 - val_loss: 0.0051 - val_acc: 0.9973
# Epoch 93/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0059 - acc: 1.0000 - val_loss: 0.0150 - val_acc: 0.9947
# Epoch 94/100
# 25/25 [==============================] - 14s 572ms/step - loss: 0.0063 - acc: 1.0000 - val_loss: 0.0047 - val_acc: 1.0000
# Epoch 95/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0056 - acc: 1.0000 - val_loss: 0.0053 - val_acc: 0.9973
# Epoch 96/100
# 25/25 [==============================] - 14s 574ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0071 - val_acc: 0.9973
# Epoch 97/100
# 25/25 [==============================] - 14s 575ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0041 - val_acc: 1.0000
# Epoch 98/100
# 25/25 [==============================] - 14s 566ms/step - loss: 0.0041 - acc: 1.0000 - val_loss: 0.0103 - val_acc: 0.9973
# Epoch 99/100
# 25/25 [==============================] - 14s 573ms/step - loss: 0.0037 - acc: 1.0000 - val_loss: 0.0170 - val_acc: 0.9920
# Epoch 100/100
# 25/25 [==============================] - 14s 571ms/step - loss: 0.0050 - acc: 1.0000 - val_loss: 0.0028 - val_acc: 1.0000

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'r', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def smooth_curve(points, factor=0.8):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points
  
plt.plot(epochs,
    smooth_curve(acc), 'r', label='Smoothed training acc')
plt.plot(epochs,
    smooth_curve(val_acc), 'b', label='Smoothed validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs,
    smooth_curve(loss), 'r', label='Smoothed training loss')
plt.plot(epochs,
    smooth_curve(val_loss), 'b', label='Smoothed validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=15,
    class_mode='categorical')

test_loss, test_acc = inception_transfer.evaluate_generator(test_generator, steps=25)
print('test acc:', test_acc)
# Out:
# Found 1061 images belonging to 2 classes.
# test acc: 1.0

# %%
from keras.applications import VGG16
from keras import backend as K
import numpy as np
import matplotlib.pyplot as plt

model = VGG16(weights='imagenet',
             include_top=False)

  
def deprocess_image(x):
  x -= x.mean()
  x /= (x.std() + 1e-5)
  x *= 0.1
  
  x += 0.5
  x = np.clip(x, 0, 1)
  
  x *= 255
  x = np.clip(x, 0, 255).astype('uint8')
  return x

def generate_pattern(layer_name, filter_index, size=100):
  layer_output=model.get_layer(layer_name).output
  loss=K.mean(layer_output[:,:,:, filter_index])

  grads=K.gradients(loss, model.input)[0]

  grads /= (K.sqrt(K.mean(K.square(grads))) + 1e-5)

  iterate = K.function([model.input], [loss, grads])

  input_image_data = np.random.random((1, size, size, 3)) * 20 + 128

  step = 1
  for i in range(40):
    loss_value, grads_value=iterate([input_image_data])
    input_image_data += grads_value * step
    
  img=input_image_data[0]
  return deprocess_image(img)

plt.imshow(generate_pattern('block3_conv1', 0))

# %%
layer_name = 'block1_conv1'
size = 64
margin=5

results=np.zeros((8* size + 7 * margin, 8 * size + 7 * margin, 3))

for i in range(8):
  for j in range(8):
    filter_img = generate_pattern(layer_name, i + (j*8), size = size)
    
    horizontal_start = i * size + i * margin
    horizontal_end = horizontal_start + size
    vertical_start = j * size + j * margin
    vertical_end = vertical_start + size
    results[horizontal_start: horizontal_end,
            vertical_start: vertical_end, :] = filter_img

plt.figure(figsize=(20,20))
plt.imshow(results)

# %%
from keras.models import load_model
from keras import optimizers
from keras.preprocessing import image
from keras.applications.resnet50 import preprocess_input
import numpy as np

model = load_model('apple_grading_model9.h5')

model.compile(loss='categorical_crossentropy',
              optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
              metrics=['accuracy'])

imagePath='dataset2/test/Apples/27b.jpg'
test_image = image.load_img(imagePath, target_size=(224,224)) 
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
#test_image = preprocess_input(test_image)
test_image /= 255.
#predict the result
result = model.predict(test_image)
print(result)

y_classes = result.argmax(axis=-1)
print(y_classes)

#print(decode_predictions(result))
# Out:
# [[9.9956709e-01 4.3294873e-04]]
# [0]

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

uploaded = drive.CreateFile({'parents': [{u'id' : '109rI9N702jHgTQHESsCXAr6EYxY62N0W'}]})
uploaded.SetContentFile('apple_checker_model.h5')
uploaded.Upload()
print('Uploaded file with ID {}'.format(uploaded.get('id')))
# Out:
# Uploaded file with ID 1CQlBBXlNEk4aeftnVnMxgkJBjuiHxVFn
